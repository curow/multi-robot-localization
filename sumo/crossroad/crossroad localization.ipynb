# %%
import os, sys
if 'SUMO_HOME' in os.environ:
    tools = os.path.join(os.environ['SUMO_HOME'], 'tools')
    sys.path.append(tools)
else:
    sys.exit("please declare environment variable 'SUMO_HOME'")
import traci
import numpy as np
import gtsam
import gtsam_unstable

sumoBinary = "/usr/local/bin/sumo"
sumoCmd = [sumoBinary, "-c", "cross.sumocfg"]

# %%
def printInfo():
    print(F"current time: {traci.simulation.getTime()}")
    print(F"current vehicle list: {traci.vehicle.getIDList()}")
    print(F"departed vehicle list: {traci.simulation.getDepartedIDList()}")
    print(F"arrived vehicle list: {traci.simulation.getArrivedIDList()}")
    ids = traci.vehicle.getIDList()
    for x in ids:
        pos = traci.vehicle.getPosition(x)
        angle = traci.vehicle.getAngle(x)
        print(F"{x}: (x:{pos[0]}, y:{pos[1]}), (angle:{angle})")
    print("\n")

lag = 10.0
smoother = gtsam_unstable.BatchFixedLagSmoother(lag)

new_factors = gtsam.NonlinearFactorGraph()
new_values = gtsam.Values()
new_timestamps = gtsam_unstable.FixedLagSmootherKeyTimestampMap()

sigma_x, sigma_y, sigma_angle = 2, 2, np.pi * 10 / 180
max_range, sigma_range = 10, 0.5
gps_noise = gtsam.noiseModel.Diagonal.Sigmas(np.array(
                        [sigma_x, sigma_y, sigma_angle]))
odom_noise = gtsam.noiseModel.Diagonal.Sigmas(np.array(
                        [sigma_x / 10, sigma_y / 10, sigma_angle / 10]))

name = {}
def symbol(x, t):
    return gtsam.symbol(name[x], t)

def pose(x):
    pos = traci.vehicle.getPosition(x)
    angle = traci.vehicle.getAngle(x) / 180 * np.pi
    return gtsam.Pose2(pos[0], pos[1], angle)

previous_states = {}

traci.start(sumoCmd)
time = 0
while time <= 63:
    if traci.vehicle.getIDCount():
        printInfo()
        ids = traci.vehicle.getIDList()
        for x in ids:
            if x not in name:
                name[x] = len(name)
            current_key = symbol(x, time)
            new_timestamps.insert((current_key, time))
            current_pose = pose(x)
            new_values.insert(current_key, current_pose)
            if x in previous_states:
                previous_key = symbol(x, time - 1)
                previous_pose = previous_states[x]
                odom_measurement = previous_pose.between(current_pose)
                odom_measurement = odom_measurement.compose()
                new_factors.push_back(gtsam.BetweenFactorPose2(
                    previous_key, current_key, , odom_noise 
                ))
            
    traci.simulationStep()
    time += 1 
traci.close()
# Out:
#  Retrying in 1 seconds
# current time: 3.0
# current vehicle list: ('DU.0',)
# departed vehicle list: ('DU.0',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:194.9), (angle:180.0)
#
#
# current time: 4.0
# current vehicle list: ('DU.0',)
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:192.75685595781542), (angle:180.0)
#
#
# current time: 5.0
# current vehicle list: ('DU.0',)
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:189.20650960281492), (angle:180.0)
#
#
# current time: 6.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ('DU.1',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:184.1202716980828), (angle:180.0)
# DU.1: (x:92.0, y:194.9), (angle:180.0)
#
#
# current time: 7.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:177.408577470202), (angle:180.0)
# DU.1: (x:92.0, y:192.95464248305652), (angle:180.0)
#
#
# current time: 8.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:168.57740427583923), (angle:180.0)
# DU.1: (x:92.0, y:189.31428018794395), (angle:180.0)
#
#
# current time: 9.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:158.90047335929285), (angle:180.0)
# DU.1: (x:92.0, y:183.3526448226068), (angle:180.0)
#
#
# current time: 10.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:149.23426695355778), (angle:180.0)
# DU.1: (x:92.0, y:176.09036685042082), (angle:180.0)
#
#
# current time: 11.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0')
# departed vehicle list: ('DU.2', 'LR.0')
# arrived vehicle list: ()
# DU.0: (x:92.0, y:138.77893012476767), (angle:180.0)
# DU.1: (x:92.0, y:167.99789987162805), (angle:180.0)
# DU.2: (x:92.0, y:194.9), (angle:180.0)
# LR.0: (x:5.1, y:92.0), (angle:90.0)
#
#
# current time: 12.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:128.47854662924735), (angle:180.0)
# DU.1: (x:92.0, y:159.45992767073915), (angle:180.0)
# DU.2: (x:92.0, y:192.91087826546283), (angle:180.0)
# LR.0: (x:7.018950720666907, y:92.0), (angle:90.0)
#
#
# current time: 13.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:118.17610085855948), (angle:180.0)
# DU.1: (x:92.0, y:150.28332622753808), (angle:180.0)
# DU.2: (x:92.0, y:188.39647619649767), (angle:180.0)
# LR.0: (x:10.660075501399115, y:92.0), (angle:90.0)
#
#
# current time: 14.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0', 'UD.0')
# departed vehicle list: ('UD.0',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:108.76879031848921), (angle:180.0)
# DU.1: (x:92.0, y:141.30963897691112), (angle:180.0)
# DU.2: (x:92.0, y:182.34872313735542), (angle:180.0)
# LR.0: (x:16.303573075984605, y:92.0), (angle:90.0)
# UD.0: (x:108.0, y:5.1), (angle:0.0)
#
#
# current time: 15.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0', 'UD.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:98.17265942717779), (angle:180.0)
# DU.1: (x:92.0, y:132.58530415420543), (angle:180.0)
# DU.2: (x:92.0, y:174.84784449953585), (angle:180.0)
# LR.0: (x:24.388655566191304, y:92.0), (angle:90.0)
# UD.0: (x:108.0, y:6.8141260907519605), (angle:0.0)
#
#
# current time: 16.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0', 'LR.1', 'UD.0')
# departed vehicle list: ('LR.1',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:87.97768672035467), (angle:180.0)
# DU.1: (x:92.0, y:124.43287805196604), (angle:180.0)
# DU.2: (x:92.0, y:166.00546879752073), (angle:180.0)
# LR.0: (x:34.673407873185354, y:92.0), (angle:90.0)
# LR.1: (x:5.1, y:92.0), (angle:90.0)
# UD.0: (x:108.0, y:11.050417199148796), (angle:0.0)
#
#
# current time: 17.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'LR.0', 'LR.1', 'UD.0')
# departed vehicle list: ('DU.3',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:78.2953320144999), (angle:180.0)
# DU.1: (x:92.0, y:115.554741170531), (angle:180.0)
# DU.2: (x:92.0, y:156.03351600170748), (angle:180.0)
# DU.3: (x:92.0, y:194.9), (angle:180.0)
# LR.0: (x:44.78231757441922, y:92.0), (angle:90.0)
# LR.1: (x:7.366701839771121, y:92.0), (angle:90.0)
# UD.0: (x:108.0, y:17.31080781966448), (angle:0.0)
#
#
# current time: 18.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'LR.0', 'LR.1', 'UD.0', 'UD.1')
# departed vehicle list: ('UD.1',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:68.75294737373967), (angle:180.0)
# DU.1: (x:92.0, y:107.47024321337241), (angle:180.0)
# DU.2: (x:92.0, y:146.7165740799747), (angle:180.0)
# DU.3: (x:92.0, y:192.94471502692903), (angle:180.0)
# LR.0: (x:54.89562503812675, y:92.0), (angle:90.0)
# LR.1: (x:12.158729705004951, y:92.0), (angle:90.0)
# UD.0: (x:108.0, y:24.873683612351307), (angle:0.0)
# UD.1: (x:108.0, y:5.1), (angle:0.0)
#
#
# current time: 19.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1')
# departed vehicle list: ('RL.0',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:59.35071966019531), (angle:180.0)
# DU.1: (x:92.0, y:98.94171810572165), (angle:180.0)
# DU.2: (x:92.0, y:137.64304243009045), (angle:180.0)
# DU.3: (x:92.0, y:188.41250884204638), (angle:180.0)
# LR.0: (x:64.8580754852271, y:92.0), (angle:90.0)
# LR.1: (x:18.71084598889574, y:92.0), (angle:90.0)
# RL.0: (x:194.9, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:34.03278259658255), (angle:0.0)
# UD.1: (x:108.0, y:6.432963024359196), (angle:0.0)
#
#
# current time: 20.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:49.3087990489521), (angle:180.0)
# DU.1: (x:92.0, y:90.44620833155946), (angle:180.0)
# DU.2: (x:92.0, y:127.93043211039739), (angle:180.0)
# DU.3: (x:92.0, y:182.4818195407046), (angle:180.0)
# LR.0: (x:75.17695294610837, y:92.0), (angle:90.0)
# LR.1: (x:26.10431301524005, y:92.0), (angle:90.0)
# RL.0: (x:192.34570911019108, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:43.32063895435773), (angle:0.0)
# UD.1: (x:108.0, y:9.262626288714818), (angle:0.0)
#
#
# current time: 21.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1')
# departed vehicle list: ('DU.4',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:39.7442245925002), (angle:180.0)
# DU.1: (x:92.0, y:82.29429021507401), (angle:180.0)
# DU.2: (x:92.0, y:118.7869906066757), (angle:180.0)
# DU.3: (x:92.0, y:174.72089273720047), (angle:180.0)
# DU.4: (x:92.0, y:194.9), (angle:180.0)
# LR.0: (x:81.64887767843557, y:92.0), (angle:90.0)
# LR.1: (x:33.95499936745183, y:92.0), (angle:90.0)
# RL.0: (x:187.26584664499387, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:52.36618124555801), (angle:0.0)
# UD.1: (x:108.0, y:14.574950293055737), (angle:0.0)
#
#
# current time: 22.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:30.019542255659914), (angle:180.0)
# DU.1: (x:92.0, y:73.77058248645643), (angle:180.0)
# DU.2: (x:92.0, y:108.86006127736941), (angle:180.0)
# DU.3: (x:92.0, y:165.46634831621776), (angle:180.0)
# DU.4: (x:92.0, y:192.56440883474426), (angle:180.0)
# LR.0: (x:84.1896310342718, y:92.0), (angle:90.0)
# LR.1: (x:40.991880301784136, y:92.0), (angle:90.0)
# RL.0: (x:180.19358085615096, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:62.355201410681545), (angle:0.0)
# UD.1: (x:108.0, y:21.343132322235032), (angle:0.0)
#
#
# current time: 23.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2')
# departed vehicle list: ('UD.2',)
# arrived vehicle list: ()
# DU.0: (x:92.0, y:19.719135372371298), (angle:180.0)
# DU.1: (x:92.0, y:64.73345495949634), (angle:180.0)
# DU.2: (x:92.0, y:99.1456606890736), (angle:180.0)
# DU.3: (x:92.0, y:155.85521615188978), (angle:180.0)
# DU.4: (x:92.0, y:188.08932136155198), (angle:180.0)
# LR.0: (x:84.84336673733868, y:92.0), (angle:90.0)
# LR.1: (x:48.06091738655526, y:92.0), (angle:90.0)
# RL.0: (x:171.2333591265108, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:72.21528032432785), (angle:0.0)
# UD.1: (x:108.0, y:29.97026083004611), (angle:0.0)
# UD.2: (x:108.0, y:5.1), (angle:0.0)
#
#
# current time: 24.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: (x:92.0, y:9.585476063032075), (angle:180.0)
# DU.1: (x:92.0, y:56.02359245083082), (angle:180.0)
# DU.2: (x:92.0, y:90.05287424298241), (angle:180.0)
# DU.3: (x:92.0, y:146.30146142573915), (angle:180.0)
# DU.4: (x:92.0, y:181.32780616027304), (angle:180.0)
# LR.0: (x:85.20245637927033, y:92.0), (angle:90.0)
# LR.1: (x:55.1762079357672, y:92.0), (angle:90.0)
# RL.0: (x:162.04997587550292, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:82.40717067086382), (angle:0.0)
# UD.1: (x:108.0, y:37.654444678960296), (angle:0.0)
# UD.2: (x:108.0, y:7.012097218306735), (angle:0.0)
#
#
# current time: 25.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2')
# departed vehicle list: ()
# arrived vehicle list: ('DU.0',)
# DU.1: (x:92.0, y:46.794244719570486), (angle:180.0)
# DU.2: (x:92.0, y:80.04869506532245), (angle:180.0)
# DU.3: (x:92.0, y:136.15970962383616), (angle:180.0)
# DU.4: (x:92.0, y:173.13640649907595), (angle:180.0)
# LR.0: (x:85.38041738525415, y:92.0), (angle:90.0)
# LR.1: (x:62.35877365915081, y:92.0), (angle:90.0)
# RL.0: (x:153.2649266208664, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:91.564071307853), (angle:0.0)
# UD.1: (x:108.0, y:45.340314173980964), (angle:0.0)
# UD.2: (x:108.0, y:10.992936124303379), (angle:0.0)
#
#
# current time: 26.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.1: (x:92.0, y:37.54475520942383), (angle:180.0)
# DU.2: (x:92.0, y:70.30267192601755), (angle:180.0)
# DU.3: (x:92.0, y:126.8079304059293), (angle:180.0)
# DU.4: (x:92.0, y:165.2044611502639), (angle:180.0)
# LR.0: (x:85.39567771534593, y:92.0), (angle:90.0)
# LR.1: (x:69.60764537163128, y:92.0), (angle:90.0)
# RL.0: (x:144.13105268623866, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:100.98184858216686), (angle:0.0)
# UD.1: (x:108.0, y:54.16899883226757), (angle:0.0)
# UD.2: (x:108.0, y:16.741467076097614), (angle:0.0)
#
#
# current time: 27.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3')
# departed vehicle list: ('UD.3',)
# arrived vehicle list: ()
# DU.1: (x:92.0, y:28.96657053088444), (angle:180.0)
# DU.2: (x:92.0, y:60.58879608709575), (angle:180.0)
# DU.3: (x:92.0, y:117.06277312873581), (angle:180.0)
# DU.4: (x:92.0, y:157.69920745584625), (angle:180.0)
# LR.0: (x:85.39803027015266, y:92.0), (angle:90.0)
# LR.1: (x:75.93102829467888, y:95.2), (angle:90.0)
# RL.0: (x:134.98908766071196, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:110.8774592701161), (angle:0.0)
# UD.1: (x:108.0, y:62.15857354041403), (angle:0.0)
# UD.2: (x:108.0, y:24.193332368112166), (angle:0.0)
# UD.3: (x:108.0, y:5.1), (angle:0.0)
#
#
# current time: 28.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.1: (x:92.0, y:20.665154350956698), (angle:180.0)
# DU.2: (x:92.0, y:51.571948209781034), (angle:180.0)
# DU.3: (x:92.0, y:107.54152724707161), (angle:180.0)
# DU.4: (x:92.0, y:149.27041402581895), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:82.29643736097502, y:95.2), (angle:90.0)
# RL.0: (x:125.99426813140093, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:120.03145099103237), (angle:0.0)
# UD.1: (x:108.0, y:70.47002934956156), (angle:0.0)
# UD.2: (x:108.0, y:33.938195400033145), (angle:0.0)
# UD.3: (x:108.0, y:6.690261032572016), (angle:0.0)
#
#
# current time: 29.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.1: (x:92.0, y:11.926708979573135), (angle:180.0)
# DU.2: (x:92.0, y:42.74597599993962), (angle:180.0)
# DU.3: (x:92.0, y:97.96250592534037), (angle:180.0)
# DU.4: (x:92.0, y:141.37689571803554), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.00585085384176, y:95.2), (angle:90.0)
# RL.0: (x:118.41119013884081, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:129.46207568112317), (angle:0.0)
# UD.1: (x:108.0, y:78.68319061481508), (angle:0.0)
# UD.2: (x:108.0, y:44.52632498028656), (angle:0.0)
# UD.3: (x:108.0, y:10.201473211380652), (angle:0.0)
#
#
# current time: 30.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ('UD.4',)
# arrived vehicle list: ()
# DU.1: (x:92.0, y:3.437001212849566), (angle:180.0)
# DU.2: (x:92.0, y:32.651848813208716), (angle:180.0)
# DU.3: (x:92.0, y:88.09012522430176), (angle:180.0)
# DU.4: (x:92.0, y:133.08936935739084), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.20722344286544, y:95.2), (angle:90.0)
# RL.0: (x:115.00176176803558, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:138.66952133013194), (angle:0.0)
# UD.1: (x:108.0, y:87.2397454244091), (angle:0.0)
# UD.2: (x:108.0, y:54.3039096483023), (angle:0.0)
# UD.3: (x:108.0, y:15.967616644315418), (angle:0.0)
# UD.4: (x:108.0, y:5.1), (angle:0.0)
#
#
# current time: 31.0
# current vehicle list: ('DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('DU.1',)
# DU.2: (x:92.0, y:22.610516998915486), (angle:180.0)
# DU.3: (x:92.0, y:78.63902796425351), (angle:180.0)
# DU.4: (x:92.0, y:124.93221365889795), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.34071477641083, y:95.2), (angle:90.0)
# RL.0: (x:114.65837860863164, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:148.96277795992353), (angle:0.0)
# UD.1: (x:108.0, y:94.91682677230344), (angle:0.0)
# UD.2: (x:108.0, y:64.9901904629301), (angle:0.0)
# UD.3: (x:108.0, y:23.823851203382947), (angle:0.0)
# UD.4: (x:108.0, y:7.466403508931398), (angle:0.0)
#
#
# current time: 32.0
# current vehicle list: ('DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.2: (x:92.0, y:13.10932899830405), (angle:180.0)
# DU.3: (x:92.0, y:68.68087995068075), (angle:180.0)
# DU.4: (x:92.0, y:117.63203016278432), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.37301551022826, y:95.2), (angle:90.0)
# RL.0: (x:114.62536336435728, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:159.06237243108248), (angle:0.0)
# UD.1: (x:108.0, y:103.7482551642876), (angle:0.0)
# UD.2: (x:108.0, y:75.47735085287003), (angle:0.0)
# UD.3: (x:108.0, y:32.79574057526422), (angle:0.0)
# UD.4: (x:108.0, y:11.32391706123017), (angle:0.0)
#
#
# current time: 33.0
# current vehicle list: ('DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.2: (x:92.0, y:3.712329344858091), (angle:180.0)
# DU.3: (x:92.0, y:59.40946808295638), (angle:180.0)
# DU.4: (x:92.0, y:109.66382215291662), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.39464564491345, y:95.2), (angle:90.0)
# RL.0: (x:114.60542328865361, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:169.05498973328184), (angle:0.0)
# UD.1: (x:108.0, y:112.53188100245691), (angle:0.0)
# UD.2: (x:108.0, y:85.80070878846877), (angle:0.0)
# UD.3: (x:108.0, y:42.85363039642576), (angle:0.0)
# UD.4: (x:108.0, y:16.873653530329463), (angle:0.0)
#
#
# current time: 34.0
# current vehicle list: ('DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('DU.2',)
# DU.3: (x:92.0, y:49.51449344808493), (angle:180.0)
# DU.4: (x:92.0, y:101.46921379760147), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.39877603313415, y:95.2), (angle:90.0)
# RL.0: (x:114.60313290529734, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:179.1763838618881), (angle:0.0)
# UD.1: (x:108.0, y:120.230510913081), (angle:0.0)
# UD.2: (x:108.0, y:95.50375390206271), (angle:0.0)
# UD.3: (x:108.0, y:52.30006494598469), (angle:0.0)
# UD.4: (x:108.0, y:24.104004932614036), (angle:0.0)
#
#
# current time: 35.0
# current vehicle list: ('DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.3: (x:92.0, y:39.97580333259157), (angle:180.0)
# DU.4: (x:92.0, y:93.96951018474607), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60197713680705, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:188.92138091717885), (angle:0.0)
# UD.1: (x:108.0, y:128.4527615702925), (angle:0.0)
# UD.2: (x:108.0, y:105.46496323393433), (angle:0.0)
# UD.3: (x:108.0, y:61.99636550607167), (angle:0.0)
# UD.4: (x:108.0, y:33.21837773763109), (angle:0.0)
#
#
# current time: 36.0
# current vehicle list: ('DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.3: (x:92.0, y:30.77356553247342), (angle:180.0)
# DU.4: (x:92.0, y:86.0049422077407), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.6012835057193, y:108.0), (angle:270.0)
# UD.0: (x:108.0, y:198.65943508542415), (angle:0.0)
# UD.1: (x:108.0, y:136.56672703549958), (angle:0.0)
# UD.2: (x:108.0, y:115.96482544290014), (angle:0.0)
# UD.3: (x:108.0, y:72.18703194933487), (angle:0.0)
# UD.4: (x:108.0, y:42.690345602090986), (angle:0.0)
#
#
# current time: 37.0
# current vehicle list: ('DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('UD.0',)
# DU.3: (x:92.0, y:21.518936901507843), (angle:180.0)
# DU.4: (x:92.0, y:77.84271698701413), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60110871926548, y:108.0), (angle:270.0)
# UD.1: (x:108.0, y:144.60843124647334), (angle:0.0)
# UD.2: (x:108.0, y:125.76295301904756), (angle:0.0)
# UD.3: (x:108.0, y:81.89238285719428), (angle:0.0)
# UD.4: (x:108.0, y:52.1330734359651), (angle:0.0)
#
#
# current time: 38.0
# current vehicle list: ('DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.3: (x:92.0, y:12.263949113372092), (angle:180.0)
# DU.4: (x:92.0, y:70.06221667516567), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60100279178428, y:108.0), (angle:270.0)
# UD.1: (x:108.0, y:152.8426892742527), (angle:0.0)
# UD.2: (x:108.0, y:134.91133407438926), (angle:0.0)
# UD.3: (x:108.0, y:91.97518412969553), (angle:0.0)
# UD.4: (x:108.0, y:61.819055228436994), (angle:0.0)
#
#
# current time: 39.0
# current vehicle list: ('DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.3: (x:92.0, y:3.1025174692550053), (angle:180.0)
# DU.4: (x:92.0, y:61.5220478996391), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60100279178428, y:108.0), (angle:270.0)
# UD.1: (x:108.0, y:161.50654367251394), (angle:0.0)
# UD.2: (x:108.0, y:143.34623967723545), (angle:0.0)
# UD.3: (x:108.0, y:101.38576219123337), (angle:0.0)
# UD.4: (x:108.0, y:71.9344304721041), (angle:0.0)
#
#
# current time: 40.0
# current vehicle list: ('DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('DU.3',)
# DU.4: (x:92.0, y:53.91132920989498), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60100279178428, y:108.0), (angle:270.0)
# UD.1: (x:108.0, y:170.14534566506768), (angle:0.0)
# UD.2: (x:108.0, y:152.1314073015154), (angle:0.0)
# UD.3: (x:108.0, y:110.51280307933703), (angle:0.0)
# UD.4: (x:108.0, y:82.12897741854917), (angle:0.0)
#
#
# current time: 41.0
# current vehicle list: ('DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.4: (x:92.0, y:45.951566047077414), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60100279178428, y:108.0), (angle:270.0)
# UD.1: (x:108.0, y:178.31529153422892), (angle:0.0)
# UD.2: (x:108.0, y:160.7655228031451), (angle:0.0)
# UD.3: (x:108.0, y:120.46511776573041), (angle:0.0)
# UD.4: (x:108.0, y:92.55645235707271), (angle:0.0)
#
#
# current time: 42.0
# current vehicle list: ('DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.4: (x:92.0, y:37.83825971697795), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60100279178428, y:108.0), (angle:270.0)
# UD.1: (x:108.0, y:186.7140955472497), (angle:0.0)
# UD.2: (x:108.0, y:168.60019938669956), (angle:0.0)
# UD.3: (x:108.0, y:129.98622184497322), (angle:0.0)
# UD.4: (x:108.0, y:102.90074596275286), (angle:0.0)
#
#
# current time: 43.0
# current vehicle list: ('DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.4: (x:92.0, y:29.46290064164613), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60100279178428, y:108.0), (angle:270.0)
# UD.1: (x:108.0, y:195.37988254234534), (angle:0.0)
# UD.2: (x:108.0, y:177.09298963808348), (angle:0.0)
# UD.3: (x:108.0, y:139.043698960338), (angle:0.0)
# UD.4: (x:108.0, y:113.21333198557744), (angle:0.0)
#
#
# current time: 44.0
# current vehicle list: ('DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('UD.1',)
# DU.4: (x:92.0, y:21.28740450005526), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60100279178428, y:108.0), (angle:270.0)
# UD.2: (x:108.0, y:186.24021499852398), (angle:0.0)
# UD.3: (x:108.0, y:148.2488550451307), (angle:0.0)
# UD.4: (x:108.0, y:123.46219111060819), (angle:0.0)
#
#
# current time: 45.0
# current vehicle list: ('DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.4: (x:92.0, y:13.737584756769607), (angle:180.0)
# LR.0: (x:85.39896226949338, y:92.0), (angle:90.0)
# LR.1: (x:85.3989060284078, y:95.2), (angle:90.0)
# RL.0: (x:114.60100279178428, y:108.0), (angle:270.0)
# UD.2: (x:108.0, y:196.91928604602992), (angle:0.0)
# UD.3: (x:108.0, y:157.78968623702903), (angle:0.0)
# UD.4: (x:108.0, y:132.6767130986746), (angle:0.0)
#
#
# current time: 46.0
# current vehicle list: ('DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('UD.2',)
# DU.4: (x:92.0, y:5.438440086587008), (angle:180.0)
# LR.0: (x:87.1853990315022, y:92.0), (angle:90.0)
# LR.1: (x:87.58094054169224, y:95.2), (angle:90.0)
# RL.0: (x:112.59724669841076, y:108.0), (angle:270.0)
# UD.3: (x:108.0, y:167.78403883774325), (angle:0.0)
# UD.4: (x:108.0, y:142.8883709409741), (angle:0.0)
#
#
# current time: 47.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('DU.4',)
# LR.0: (x:90.32741915688663, y:92.0), (angle:90.0)
# LR.1: (x:91.42833328779989, y:95.2), (angle:90.0)
# RL.0: (x:108.10074112294666, y:108.0), (angle:270.0)
# UD.3: (x:108.0, y:176.91365724714967), (angle:0.0)
# UD.4: (x:108.0, y:152.48279899331246), (angle:0.0)
#
#
# current time: 48.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:94.97574011807144, y:92.0), (angle:90.0)
# LR.1: (x:97.64009766792616, y:95.2), (angle:90.0)
# RL.0: (x:101.74105135084088, y:108.0), (angle:270.0)
# UD.3: (x:108.0, y:186.2208396343098), (angle:0.0)
# UD.4: (x:108.0, y:162.0710190806857), (angle:0.0)
#
#
# current time: 49.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:101.08212265931348, y:92.0), (angle:90.0)
# LR.1: (x:105.9290957314409, y:95.2), (angle:90.0)
# RL.0: (x:92.83245765602175, y:108.0), (angle:270.0)
# UD.3: (x:108.0, y:196.40370089653445), (angle:0.0)
# UD.4: (x:108.0, y:171.616639892211), (angle:0.0)
#
#
# current time: 50.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('UD.3',)
# LR.0: (x:109.7395215452211, y:92.0), (angle:90.0)
# LR.1: (x:114.07034831768716, y:95.2), (angle:90.0)
# RL.0: (x:83.84026176370801, y:108.0), (angle:270.0)
# UD.4: (x:108.0, y:181.58061256459297), (angle:0.0)
#
#
# current time: 51.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:120.02363603737405, y:92.0), (angle:90.0)
# LR.1: (x:121.29535316417417, y:95.2), (angle:90.0)
# RL.0: (x:75.06816383634978, y:108.0), (angle:270.0)
# UD.4: (x:108.0, y:191.5559449828676), (angle:0.0)
#
#
# current time: 52.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ('UD.4',)
# LR.0: (x:130.33185711855654, y:92.0), (angle:90.0)
# LR.1: (x:129.1867588819706, y:95.2), (angle:90.0)
# RL.0: (x:66.85485274269693, y:108.0), (angle:270.0)
#
#
# current time: 53.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:141.13676298215557, y:92.0), (angle:90.0)
# LR.1: (x:137.34791150004708, y:95.2), (angle:90.0)
# RL.0: (x:57.645114427028744, y:108.0), (angle:270.0)
#
#
# current time: 54.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:150.7263777005203, y:92.0), (angle:90.0)
# LR.1: (x:145.0286066749151, y:95.2), (angle:90.0)
# RL.0: (x:48.86183044054854, y:108.0), (angle:270.0)
#
#
# current time: 55.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:161.15052148888233, y:92.0), (angle:90.0)
# LR.1: (x:152.46934090373358, y:95.2), (angle:90.0)
# RL.0: (x:39.77303785116883, y:108.0), (angle:270.0)
#
#
# current time: 56.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:171.64650741040506, y:92.0), (angle:90.0)
# LR.1: (x:159.6206735848016, y:95.2), (angle:90.0)
# RL.0: (x:31.304809000838375, y:108.0), (angle:270.0)
#
#
# current time: 57.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:181.51895978730823, y:92.0), (angle:90.0)
# LR.1: (x:167.32536973280764, y:95.2), (angle:90.0)
# RL.0: (x:22.232803358164205, y:108.0), (angle:270.0)
#
#
# current time: 58.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: (x:191.7795750550564, y:92.0), (angle:90.0)
# LR.1: (x:175.2671806787188, y:95.2), (angle:90.0)
# RL.0: (x:13.540274289786169, y:108.0), (angle:270.0)
#
#
# current time: 59.0
# current vehicle list: ('LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ('LR.0',)
# LR.1: (x:182.79525001505937, y:95.2), (angle:90.0)
# RL.0: (x:5.173695975399625, y:108.0), (angle:270.0)
#
#
# current time: 60.0
# current vehicle list: ('LR.1',)
# departed vehicle list: ()
# arrived vehicle list: ('RL.0',)
# LR.1: (x:190.74460783594444, y:95.2), (angle:90.0)
#
#
# current time: 61.0
# current vehicle list: ('LR.1',)
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.1: (x:198.29013951302736, y:95.2), (angle:90.0)
