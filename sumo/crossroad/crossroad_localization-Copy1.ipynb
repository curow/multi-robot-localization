# %%
import os, sys
if 'SUMO_HOME' in os.environ:
    tools = os.path.join(os.environ['SUMO_HOME'], 'tools')
    sys.path.append(tools)
else:
    sys.exit("please declare environment variable 'SUMO_HOME'")
import traci
import numpy as np
import pandas as pd
import gtsam
import gtsam_unstable

# %%
sumoBinary = "/usr/local/bin/sumo"
sumoCmd = [sumoBinary, "-c", "cross.sumocfg"]

seed = 1
randomState = np.random.RandomState(seed)

# %%
def printInfo():
    print(F"current time: {traci.simulation.getTime()}")
    print(F"current vehicle list: {traci.vehicle.getIDList()}")
    print(F"departed vehicle list: {traci.simulation.getDepartedIDList()}")
    print(F"arrived vehicle list: {traci.simulation.getArrivedIDList()}")
    ids = traci.vehicle.getIDList()
    for x in ids:
        pos = traci.vehicle.getPosition(x)
        angle = traci.vehicle.getAngle(x)
        print(F"{x}: x:{pos[0]}, y:{pos[1]}, angle:{angle / 180 * np.pi}")
    print("\n")

# %%
max_range = 20

gps_sigma_x, gps_sigma_y, gps_sigma_angle = 5, 5, np.pi * 20 / 180
odom_sigma_x, odom_sigma_y, odom_sigma_angle = gps_sigma_x / 10, gps_sigma_y / 10, gps_sigma_angle / 10
relative_sigma_x, relative_sigma_y, relative_sigma_angle = gps_sigma_x / 10, gps_sigma_y / 10, gps_sigma_angle / 10

gps_noise = gtsam.noiseModel.Diagonal.Sigmas(np.array(
                        [gps_sigma_x, gps_sigma_y, gps_sigma_angle]))
odom_noise = gtsam.noiseModel.Diagonal.Sigmas(np.array(
                        [odom_sigma_x, odom_sigma_y, odom_sigma_angle]))
relative_noise = gtsam.noiseModel.Diagonal.Sigmas(np.array(
                        [relative_sigma_x, relative_sigma_y, relative_sigma_angle]))

# %%
lag = 10.0
smoother = gtsam_unstable.BatchFixedLagSmoother(lag)

new_factors = gtsam.NonlinearFactorGraph()
new_values = gtsam.Values()
new_timestamps = gtsam_unstable.FixedLagSmootherKeyTimestampMap()
name = {}

# %%
def symbol(x, t):
    return (name[x] << 15) + t

def pose(x):
    pos = traci.vehicle.getPosition(x)
    angle = traci.vehicle.getAngle(x) / 180 * np.pi
    return gtsam.Pose2(pos[0], pos[1], angle)

def noise_gps_measurement(x):
    current_pose = pose(x)
    noise_x = randomState.normal(0.0, gps_sigma_x)
    noise_y = randomState.normal(0.0, gps_sigma_y)
    noise_angle = randomState.normal(0.0, gps_sigma_angle)
    gps_measurement = current_pose.compose(gtsam.Pose2(
        noise_x, noise_y, noise_angle
    ))
    return gps_measurement

previous_states = {}
current_states = {}
def noise_odom_measurement(x):
    previous_pose = previous_states[x]
    current_pose = current_states[x]
    odom_measurement = previous_pose.between(current_pose)
    noise_x = randomState.normal(0.0, odom_sigma_x)
    noise_y = randomState.normal(0.0, odom_sigma_y)
    noise_angle = randomState.normal(0.0, odom_sigma_angle)
    odom_measurement = odom_measurement.compose(gtsam.Pose2(
        noise_x, noise_y, noise_angle
    ))
    return odom_measurement

def noise_relative_measurement(x, y):
    relative_measurement = pose(x).between(pose(y))
    noise_x = randomState.normal(0.0, relative_sigma_x)
    noise_y = randomState.normal(0.0, relative_sigma_y)
    noise_angle = randomState.normal(0.0, relative_sigma_angle)
    relative_measurement = relative_measurement.compose(gtsam.Pose2(
        noise_x, noise_y, noise_angle
    ))
    return relative_measurement

def euclidean_distance(x, y):
    pos_x = np.array(traci.vehicle.getPosition(x))
    pos_y = np.array(traci.vehicle.getPosition(y))
    return np.linalg.norm(pos_x - pos_y)

# %%
traci.start(sumoCmd)
data = []
time = 0
while time <= 63:
    print(F"time: {time}")
    if not traci.vehicle.getIDCount():
        traci.simulationStep()
        time += 1 
        continue
    printInfo()
    ids = traci.vehicle.getIDList()
    for x in ids:
        if x not in name:
            name[x] = len(name)

        current_key = symbol(x, time)
        new_timestamps.insert((current_key, time))

        # absolute measurement
        gps_measurement = noise_gps_measurement(x)
        new_factors.push_back(gtsam.PriorFactorPose2(
            current_key, gps_measurement, gps_noise
        ))
        new_values.insert(current_key, gps_measurement)
        
        current_states[x] = gps_measurement
        
        # temperal relative measurement
        if x in previous_states:
            previous_key = symbol(x, time - 1)
            odom_measurement = noise_odom_measurement(x)
            new_factors.push_back(gtsam.BetweenFactorPose2(
                previous_key, current_key, odom_measurement, odom_noise 
            ))

    # spatial relative measurement
#     for i in ids:
#         for j in ids:
#             if i == j or euclidean_distance(i, j) > max_range:
#                 continue
#             relative_measurement = noise_relative_measurement(i, j)
#             new_factors.push_back(gtsam.BetweenFactorPose2(
#                 symbol(i, time), symbol(j, time), relative_measurement, relative_noise
#             ))
            
    smoother.update(new_factors, new_values, new_timestamps)
    print("after optimization:")
    for x in ids:
        current_key = symbol(x, time)
        estimation = smoother.calculateEstimatePose2(current_key)
        groundtruth = pose(x)
        difference = groundtruth.between(estimation)
        print("Timestamp = " + str(time) + ", Vehicle = " + x)
        print(F"Estimation: {estimation}")
        print(F"GroundTruth: {groundtruth}")
        print(F"Difference: {groundtruth.x() - estimation.x(), groundtruth.y() - estimation.y(), difference.theta()}")
        value = {
            "timestamp": time, "vehicle": x, 
            "groundtruth_x":groundtruth.x(),
            "groundtruth_y":groundtruth.y(),
            "groundtruth_theta":groundtruth.theta(),
            "estimation_x":estimation.x(),
            "estimation_y":estimation.y(),
            "estimation_theta":estimation.theta(),
            "difference_x":groundtruth.x() - estimation.x(),
            "difference_y":groundtruth.y() - estimation.y(),
            "difference_theta":difference.theta(),
        }
        data.append(value)
    print('\n')

    print(F"end time {time}\n")

    new_timestamps.clear()
    new_values.clear()
    new_factors.resize(0)
    previous_states = current_states
    current_states = {}
            
    traci.simulationStep()
    time += 1 
df = pd.DataFrame(data)
df.to_csv("cooperative-localization-result.csv", index=False)
traci.close()
# Out:
#  Retrying in 1 seconds
# time: 0
# time: 1
# time: 2
# time: 3
# current time: 3.0
# current vehicle list: ('DU.0',)
# departed vehicle list: ('DU.0',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:194.9, angle:3.141592653589793
#
#
# after optimization:
# Timestamp = 3, Vehicle = DU.0
# Estimation: (83.8783, 197.959, 2.95723)
#
# GroundTruth: (92, 194.9, 3.14159)
#
# Difference: (8.121726818316205, -3.058782068250366, -0.1843667218605023)
#
#
# end time 3
#
# time: 4
# current time: 4.0
# current vehicle list: ('DU.0',)
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:192.75685595781542, angle:3.141592653589793
#
#
# after optimization:
# Timestamp = 4, Vehicle = DU.0
# Estimation: (97.1459, 188.793, 2.33694)
#
# GroundTruth: (92, 192.757, 3.14159)
#
# Difference: (-5.145925844957162, 3.9641324318155, -0.8046570921904579)
#
#
# end time 4
#
# time: 5
# current time: 5.0
# current vehicle list: ('DU.0',)
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:189.20650960281492, angle:3.141592653589793
#
#
# after optimization:
# Timestamp = 5, Vehicle = DU.0
# Estimation: (93.1855, 182.147, 2.45003)
#
# GroundTruth: (92, 189.207, 3.14159)
#
# Difference: (-1.1854749392215211, 7.0592849402083, -0.6915617655597618)
#
#
# end time 5
#
# time: 6
# current time: 6.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ('DU.1',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:184.1202716980828, angle:3.141592653589793
# DU.1: x:92.0, y:194.9, angle:3.141592653589793
#
#
# after optimization:
# Timestamp = 6, Vehicle = DU.0
# Estimation: (97.3228, 185.062, 2.82684)
#
# GroundTruth: (92, 184.12, 3.14159)
#
# Difference: (-5.322751973733091, -0.9412971171949494, -0.3147553384403989)
# Timestamp = 6, Vehicle = DU.1
# Estimation: (86.2764, 190.392, -2.96619)
#
# GroundTruth: (92, 194.9, 3.14159)
#
# Difference: (5.723618549198065, 4.5079536029639655, 0.17540361372939653)
#
#
# end time 6
#
# time: 7
# current time: 7.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:177.408577470202, angle:3.141592653589793
# DU.1: x:92.0, y:192.95464248305652, angle:3.141592653589793
#
#
# after optimization:
# Timestamp = 7, Vehicle = DU.0
# Estimation: (87.6931, 181.049, 3.10702)
#
# GroundTruth: (92, 177.409, 3.14159)
#
# Difference: (4.306884834353539, -3.640776418132589, -0.03457391579402924)
# Timestamp = 7, Vehicle = DU.1
# Estimation: (95.7013, 195.052, 2.90165)
#
# GroundTruth: (92, 192.955, 3.14159)
#
# Difference: (-3.70134237850948, -2.0977585460243517, -0.23994712860478737)
#
#
# end time 7
#
# time: 8
# current time: 8.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:168.57740427583923, angle:3.141592653589793
# DU.1: x:92.0, y:189.31428018794395, angle:3.141592653589793
#
#
# after optimization:
# Timestamp = 8, Vehicle = DU.0
# Estimation: (97.5829, 167.565, -2.58205)
#
# GroundTruth: (92, 168.577, 3.14159)
#
# Difference: (-5.582902079320974, 1.0122049779436963, 0.5595432525048114)
# Timestamp = 8, Vehicle = DU.1
# Estimation: (95.9109, 180.782, -3.07608)
#
# GroundTruth: (92, 189.314, 3.14159)
#
# Difference: (-3.910881329736071, 8.5320632914258, 0.06550930040365775)
#
#
# end time 8
#
# time: 9
# current time: 9.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:158.90047335929285, angle:3.141592653589793
# DU.1: x:92.0, y:183.3526448226068, angle:3.141592653589793
#
#
# after optimization:
# Timestamp = 9, Vehicle = DU.0
# Estimation: (91.3985, 156.536, -3.0643)
#
# GroundTruth: (92, 158.9, 3.14159)
#
# Difference: (0.6014819650888228, 2.364782251987549, 0.0772950636089768)
# Timestamp = 9, Vehicle = DU.1
# Estimation: (92.811, 180.057, -2.78517)
#
# GroundTruth: (92, 183.353, 3.14159)
#
# Difference: (-0.811037296224228, 3.295813386432286, 0.35642072455800206)
#
#
# end time 9
#
# time: 10
# current time: 10.0
# current vehicle list: ('DU.0', 'DU.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:149.23426695355778, angle:3.141592653589793
# DU.1: x:92.0, y:176.09036685042082, angle:3.141592653589793
#
#
# after optimization:
# Timestamp = 10, Vehicle = DU.0
# Estimation: (95.7094, 143.307, -2.98938)
#
# GroundTruth: (92, 149.234, 3.14159)
#
# Difference: (-3.7093650673782435, 5.927040979251672, 0.15220844998962724)
# Timestamp = 10, Vehicle = DU.1
# Estimation: (86.5807, 168.727, -2.3432)
#
# GroundTruth: (92, 176.09, 3.14159)
#
# Difference: (5.419332520480538, 7.363262391681076, 0.7983906640598198)
#
#
# end time 10
#
# time: 11
# current time: 11.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0')
# departed vehicle list: ('DU.2', 'LR.0')
# arrived vehicle list: ()
# DU.0: x:92.0, y:138.77893012476767, angle:3.141592653589793
# DU.1: x:92.0, y:167.99789987162805, angle:3.141592653589793
# DU.2: x:92.0, y:194.9, angle:3.141592653589793
# LR.0: x:5.1, y:92.0, angle:1.5707963267948966
#
#
# after optimization:
# Timestamp = 11, Vehicle = DU.0
# Estimation: (91.6639, 135.009, -3.03387)
#
# GroundTruth: (92, 138.779, 3.14159)
#
# Difference: (0.33611481731173853, 3.7703876638225324, 0.10772669557514332)
# Timestamp = 11, Vehicle = DU.1
# Estimation: (91.1159, 164.434, 3.10417)
#
# GroundTruth: (92, 167.998, 3.14159)
#
# Difference: (0.8841194130745151, 3.5643727482889176, -0.03742727231072246)
# Timestamp = 11, Vehicle = DU.2
# Estimation: (91.0085, 194.305, 2.90749)
#
# GroundTruth: (92, 194.9, 3.14159)
#
# Difference: (0.9914986006338466, 0.5950432290372873, -0.23410530129392812)
# Timestamp = 11, Vehicle = LR.0
# Estimation: (4.49089, 93.8878, 1.96506)
#
# GroundTruth: (5.1, 92, 1.5708)
#
# Difference: (0.6091063549571842, -1.887818931604599, 0.3942642608271086)
#
#
# end time 11
#
# time: 12
# current time: 12.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:128.47854662924735, angle:3.141592653589793
# DU.1: x:92.0, y:159.45992767073915, angle:3.141592653589793
# DU.2: x:92.0, y:192.91087826546283, angle:3.141592653589793
# LR.0: x:7.018950720666907, y:92.0, angle:1.5707963267948966
#
#
# after optimization:
# Timestamp = 12, Vehicle = DU.0
# Estimation: (86.5255, 127.897, 3.0072)
#
# GroundTruth: (92, 128.479, 3.14159)
#
# Difference: (5.474476952534033, 0.5818164588212937, -0.13439055783113554)
# Timestamp = 12, Vehicle = DU.1
# Estimation: (93.7148, 159.762, 2.9979)
#
# GroundTruth: (92, 159.46, 3.14159)
#
# Difference: (-1.7148021272105183, -0.30202643701082366, -0.14369003841237488)
# Timestamp = 12, Vehicle = DU.2
# Estimation: (89.9141, 189.778, 2.74315)
#
# GroundTruth: (92, 192.911, 3.14159)
#
# Difference: (2.0859242753997194, 3.1332073499722526, -0.3984458328879544)
# Timestamp = 12, Vehicle = LR.0
# Estimation: (6.72652, 90.851, 1.07653)
#
# GroundTruth: (7.01895, 92, 1.5708)
#
# Difference: (0.29243450267031257, 1.1490217722912917, -0.4942695302310096)
#
#
# end time 12
#
# time: 13
# current time: 13.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:118.17610085855948, angle:3.141592653589793
# DU.1: x:92.0, y:150.28332622753808, angle:3.141592653589793
# DU.2: x:92.0, y:188.39647619649767, angle:3.141592653589793
# LR.0: x:10.660075501399115, y:92.0, angle:1.5707963267948966
#
#
# after optimization:
# Timestamp = 13, Vehicle = DU.0
# Estimation: (91.2053, 124.526, 3.13245)
#
# GroundTruth: (92, 118.176, 3.14159)
#
# Difference: (0.7947019644234246, -6.349667656938735, -0.009145532130958822)
# Timestamp = 13, Vehicle = DU.1
# Estimation: (91.2751, 154.791, -2.58579)
#
# GroundTruth: (92, 150.283, 3.14159)
#
# Difference: (0.7248757426704202, -4.507644782448551, 0.5558071075792752)
# Timestamp = 13, Vehicle = DU.2
# Estimation: (83.6009, 186.767, 2.70095)
#
# GroundTruth: (92, 188.396, 3.14159)
#
# Difference: (8.399082648800771, 1.629308085117259, -0.4406381954143815)
# Timestamp = 13, Vehicle = LR.0
# Estimation: (7.74867, 85.7418, 1.81305)
#
# GroundTruth: (10.6601, 92, 1.5708)
#
# Difference: (2.9114045089539067, 6.258229890063333, 0.24224945465940273)
#
#
# end time 13
#
# time: 14
# current time: 14.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0', 'UD.0')
# departed vehicle list: ('UD.0',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:108.76879031848921, angle:3.141592653589793
# DU.1: x:92.0, y:141.30963897691112, angle:3.141592653589793
# DU.2: x:92.0, y:182.34872313735542, angle:3.141592653589793
# LR.0: x:16.303573075984605, y:92.0, angle:1.5707963267948966
# UD.0: x:108.0, y:5.1, angle:0.0
#
#
# after optimization:
# Timestamp = 14, Vehicle = DU.0
# Estimation: (88.6566, 107.971, 3.09908)
#
# GroundTruth: (92, 108.769, 3.14159)
#
# Difference: (3.343416448259376, 0.7980305677648971, -0.04251614154718705)
# Timestamp = 14, Vehicle = DU.1
# Estimation: (89.4077, 140.858, -2.99214)
#
# GroundTruth: (92, 141.31, 3.14159)
#
# Difference: (2.5923339881605045, 0.45149486792507787, 0.1494527288199985)
# Timestamp = 14, Vehicle = DU.2
# Estimation: (92.7595, 194, -2.799)
#
# GroundTruth: (92, 182.349, 3.14159)
#
# Difference: (-0.7594881109880589, -11.651661428008481, 0.3425928787194922)
# Timestamp = 14, Vehicle = LR.0
# Estimation: (17.0887, 90.7721, 1.53173)
#
# GroundTruth: (16.3036, 92, 1.5708)
#
# Difference: (-0.7851111084772917, 1.2279319094187855, -0.03907028063058952)
# Timestamp = 14, Vehicle = UD.0
# Estimation: (109.244, 3.61679, 0.172861)
#
# GroundTruth: (108, 5.1, 0)
#
# Difference: (-1.2439958069388553, 1.4832057618543137, 0.17286136193151508)
#
#
# end time 14
#
# time: 15
# current time: 15.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0', 'UD.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:98.17265942717779, angle:3.141592653589793
# DU.1: x:92.0, y:132.58530415420543, angle:3.141592653589793
# DU.2: x:92.0, y:174.84784449953585, angle:3.141592653589793
# LR.0: x:24.388655566191304, y:92.0, angle:1.5707963267948966
# UD.0: x:108.0, y:6.8141260907519605, angle:0.0
#
#
# after optimization:
# Timestamp = 15, Vehicle = DU.0
# Estimation: (92.7577, 93.5855, -3.06621)
#
# GroundTruth: (92, 98.1727, 3.14159)
#
# Difference: (-0.757658528671314, 4.5871869487899914, 0.07538105011710645)
# Timestamp = 15, Vehicle = DU.1
# Estimation: (88.6903, 120.226, -3.08895)
#
# GroundTruth: (92, 132.585, 3.14159)
#
# Difference: (3.309663662795842, 12.35968043212543, 0.05263824680632428)
# Timestamp = 15, Vehicle = DU.2
# Estimation: (93.0781, 170.876, 3.03654)
#
# GroundTruth: (92, 174.848, 3.14159)
#
# Difference: (-1.0780747028772595, 3.971665771919561, -0.10505322360457611)
# Timestamp = 15, Vehicle = LR.0
# Estimation: (25.2257, 98.147, 1.33319)
#
# GroundTruth: (24.3887, 92, 1.5708)
#
# Difference: (-0.8370069381935821, -6.147027663006625, -0.23760427863346953)
# Timestamp = 15, Vehicle = UD.0
# Estimation: (108.071, 12.951, 0.15126)
#
# GroundTruth: (108, 6.81413, 0)
#
# Difference: (-0.07115196210104102, -6.136900920006385, 0.15126028230716293)
#
#
# end time 15
#
# time: 16
# current time: 16.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'LR.0', 'LR.1', 'UD.0')
# departed vehicle list: ('LR.1',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:87.97768672035467, angle:3.141592653589793
# DU.1: x:92.0, y:124.43287805196604, angle:3.141592653589793
# DU.2: x:92.0, y:166.00546879752073, angle:3.141592653589793
# LR.0: x:34.673407873185354, y:92.0, angle:1.5707963267948966
# LR.1: x:5.1, y:92.0, angle:1.5707963267948966
# UD.0: x:108.0, y:11.050417199148796, angle:0.0
#
#
# after optimization:
# Timestamp = 16, Vehicle = DU.0
# Estimation: (99.8638, 84.789, -3.00492)
#
# GroundTruth: (92, 87.9777, 3.14159)
#
# Difference: (-7.863766189219049, 3.188660971560651, 0.13666792408136233)
# Timestamp = 16, Vehicle = DU.1
# Estimation: (87.8203, 128.44, -2.38145)
#
# GroundTruth: (92, 124.433, 3.14159)
#
# Difference: (4.1796739753499, -4.006735314713751, 0.760144836921993)
# Timestamp = 16, Vehicle = DU.2
# Estimation: (95.9059, 171.655, -2.41475)
#
# GroundTruth: (92, 166.005, 3.14159)
#
# Difference: (-3.9058593227400706, -5.649580313124318, 0.7268461916940001)
# Timestamp = 16, Vehicle = LR.0
# Estimation: (41.0173, 88.8262, 1.90368)
#
# GroundTruth: (34.6734, 92, 1.5708)
#
# Difference: (-6.343876072146664, 3.173843718367962, 0.33288225346642064)
# Timestamp = 16, Vehicle = LR.1
# Estimation: (-2.98475, 92.6455, 1.74629)
#
# GroundTruth: (5.1, 92, 1.5708)
#
# Difference: (8.0847479942865, -0.6455078985536318, 0.17548967350557249)
# Timestamp = 16, Vehicle = UD.0
# Estimation: (116.766, 11.4658, -0.40883)
#
# GroundTruth: (108, 11.0504, 0)
#
# Difference: (-8.765841193207692, -0.4154321321350878, -0.4088301255512022)
#
#
# end time 16
#
# time: 17
# current time: 17.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'LR.0', 'LR.1', 'UD.0')
# departed vehicle list: ('DU.3',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:78.2953320144999, angle:3.141592653589793
# DU.1: x:92.0, y:115.554741170531, angle:3.141592653589793
# DU.2: x:92.0, y:156.03351600170748, angle:3.141592653589793
# DU.3: x:92.0, y:194.9, angle:3.141592653589793
# LR.0: x:44.78231757441922, y:92.0, angle:1.5707963267948966
# LR.1: x:7.366701839771121, y:92.0, angle:1.5707963267948966
# UD.0: x:108.0, y:17.31080781966448, angle:0.0
#
#
# after optimization:
# Timestamp = 17, Vehicle = DU.0
# Estimation: (95.1679, 78.8979, -3.00503)
#
# GroundTruth: (92, 78.2953, 3.14159)
#
# Difference: (-3.167876713389248, -0.6025251539586094, 0.1365594458778902)
# Timestamp = 17, Vehicle = DU.1
# Estimation: (93.2328, 123.683, 2.82364)
#
# GroundTruth: (92, 115.555, 3.14159)
#
# Difference: (-1.2327565849859212, -8.127925610996797, -0.3179498569116249)
# Timestamp = 17, Vehicle = DU.2
# Estimation: (94.8515, 157.924, -3.08799)
#
# GroundTruth: (92, 156.034, 3.14159)
#
# Difference: (-2.8514890879802834, -1.8907954497971957, 0.053600050053393265)
# Timestamp = 17, Vehicle = DU.3
# Estimation: (88.9073, 197.116, -2.5096)
#
# GroundTruth: (92, 194.9, 3.14159)
#
# Difference: (3.0926956539314716, -2.215859653503202, 0.63199590947604)
# Timestamp = 17, Vehicle = LR.0
# Estimation: (45.9084, 84.4999, 1.53931)
#
# GroundTruth: (44.7823, 92, 1.5708)
#
# Difference: (-1.126066638460685, 7.500131571880033, -0.03148260334664324)
# Timestamp = 17, Vehicle = LR.1
# Estimation: (-2.77288, 86.9117, 1.77539)
#
# GroundTruth: (7.3667, 92, 1.5708)
#
# Difference: (10.139586778405473, 5.088269364535108, 0.20459344149244676)
# Timestamp = 17, Vehicle = UD.0
# Estimation: (101.035, 21.4013, -0.100052)
#
# GroundTruth: (108, 17.3108, 0)
#
# Difference: (6.964760751854101, -4.090515010910689, -0.10005236210194954)
#
#
# end time 17
#
# time: 18
# current time: 18.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'LR.0', 'LR.1', 'UD.0', 'UD.1')
# departed vehicle list: ('UD.1',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:68.75294737373967, angle:3.141592653589793
# DU.1: x:92.0, y:107.47024321337241, angle:3.141592653589793
# DU.2: x:92.0, y:146.7165740799747, angle:3.141592653589793
# DU.3: x:92.0, y:192.94471502692903, angle:3.141592653589793
# LR.0: x:54.89562503812675, y:92.0, angle:1.5707963267948966
# LR.1: x:12.158729705004951, y:92.0, angle:1.5707963267948966
# UD.0: x:108.0, y:24.873683612351307, angle:0.0
# UD.1: x:108.0, y:5.1, angle:0.0
#
#
# after optimization:
# Timestamp = 18, Vehicle = DU.0
# Estimation: (90.4013, 66.2018, 2.96066)
#
# GroundTruth: (92, 68.7529, 3.14159)
#
# Difference: (1.5986602535744083, 2.551189874128056, -0.18093354374903844)
# Timestamp = 18, Vehicle = DU.1
# Estimation: (89.1089, 112.559, 2.90929)
#
# GroundTruth: (92, 107.47, 3.14159)
#
# Difference: (2.8910518368069233, -5.088845853263322, -0.23229789346828214)
# Timestamp = 18, Vehicle = DU.2
# Estimation: (85.3325, 150.154, 3.03481)
#
# GroundTruth: (92, 146.717, 3.14159)
#
# Difference: (6.6675334089195815, -3.4378276882411, -0.10678459597275021)
# Timestamp = 18, Vehicle = DU.3
# Estimation: (91.2235, 192.86, -3.08585)
#
# GroundTruth: (92, 192.945, 3.14159)
#
# Difference: (0.7764521745708635, 0.0851188796827671, 0.05574267110999177)
# Timestamp = 18, Vehicle = LR.0
# Estimation: (51.7767, 91.1018, 1.39669)
#
# GroundTruth: (54.8956, 92, 1.5708)
#
# Difference: (3.118905511798218, 0.8981767046435323, -0.1741055682937024)
# Timestamp = 18, Vehicle = LR.1
# Estimation: (17.3949, 96.6564, 1.73759)
#
# GroundTruth: (12.1587, 92, 1.5708)
#
# Difference: (-5.236122598575232, -4.65637963942163, 0.16678946750006676)
# Timestamp = 18, Vehicle = UD.0
# Estimation: (104.248, 23.4304, 0.615217)
#
# GroundTruth: (108, 24.8737, 0)
#
# Difference: (3.751526520286447, 1.4433077672027075, 0.6152167307437557)
# Timestamp = 18, Vehicle = UD.1
# Estimation: (105.001, 10.7171, 0.106558)
#
# GroundTruth: (108, 5.1, 0)
#
# Difference: (2.9990226553542385, -5.617060810109676, 0.10655829900152043)
#
#
# end time 18
#
# time: 19
# current time: 19.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1')
# departed vehicle list: ('RL.0',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:59.35071966019531, angle:3.141592653589793
# DU.1: x:92.0, y:98.94171810572165, angle:3.141592653589793
# DU.2: x:92.0, y:137.64304243009045, angle:3.141592653589793
# DU.3: x:92.0, y:188.41250884204638, angle:3.141592653589793
# LR.0: x:64.8580754852271, y:92.0, angle:1.5707963267948966
# LR.1: x:18.71084598889574, y:92.0, angle:1.5707963267948966
# RL.0: x:194.9, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:34.03278259658255, angle:0.0
# UD.1: x:108.0, y:6.432963024359196, angle:0.0
#
#
# after optimization:
# Timestamp = 19, Vehicle = DU.0
# Estimation: (85.079, 60.8345, -2.01784)
#
# GroundTruth: (92, 59.3507, 3.14159)
#
# Difference: (6.920998158721943, -1.4838301496670994, 1.1237509898084386)
# Timestamp = 19, Vehicle = DU.1
# Estimation: (97.4154, 104.197, 3.11934)
#
# GroundTruth: (92, 98.9417, 3.14159)
#
# Difference: (-5.41544043607729, -5.255609250088554, -0.022247708064955247)
# Timestamp = 19, Vehicle = DU.2
# Estimation: (89.1083, 132.841, 2.9718)
#
# GroundTruth: (92, 137.643, 3.14159)
#
# Difference: (2.8917082840399644, 4.802058996792141, -0.1697933016501052)
# Timestamp = 19, Vehicle = DU.3
# Estimation: (89.8834, 182.341, 2.77356)
#
# GroundTruth: (92, 188.413, 3.14159)
#
# Difference: (2.1165707560198683, 6.071191026054919, -0.36802770672199697)
# Timestamp = 19, Vehicle = LR.0
# Estimation: (73.9435, 81.6496, 0.799613)
#
# GroundTruth: (64.8581, 92, 1.5708)
#
# Difference: (-9.085383443324176, 10.350428775633887, -0.7711832026837301)
# Timestamp = 19, Vehicle = LR.1
# Estimation: (17.3266, 90.338, 1.49023)
#
# GroundTruth: (18.7108, 92, 1.5708)
#
# Difference: (1.3842673076139036, 1.6619668955520552, -0.08056881685584216)
# Timestamp = 19, Vehicle = RL.0
# Estimation: (189.02, 105.694, -1.2182)
#
# GroundTruth: (194.9, 108, -1.5708)
#
# Difference: (5.87991335720659, 2.305820499885087, 0.3526009021673516)
# Timestamp = 19, Vehicle = UD.0
# Estimation: (112.64, 33.0352, 0.328041)
#
# GroundTruth: (108, 34.0328, 0)
#
# Difference: (-4.639547430650268, 0.9975525859871937, 0.3280412532087565)
# Timestamp = 19, Vehicle = UD.1
# Estimation: (107.064, 4.48035, -0.270156)
#
# GroundTruth: (108, 6.43296, 0)
#
# Difference: (0.9363648248490364, 1.952612617888268, -0.2701560937256444)
#
#
# end time 19
#
# time: 20
# current time: 20.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:49.3087990489521, angle:3.141592653589793
# DU.1: x:92.0, y:90.44620833155946, angle:3.141592653589793
# DU.2: x:92.0, y:127.93043211039739, angle:3.141592653589793
# DU.3: x:92.0, y:182.4818195407046, angle:3.141592653589793
# LR.0: x:75.17695294610837, y:92.0, angle:1.5707963267948966
# LR.1: x:26.10431301524005, y:92.0, angle:1.5707963267948966
# RL.0: x:192.34570911019108, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:43.32063895435773, angle:0.0
# UD.1: x:108.0, y:9.262626288714818, angle:0.0
#
#
# after optimization:
# Timestamp = 20, Vehicle = DU.0
# Estimation: (90.2472, 50.2997, -2.8063)
#
# GroundTruth: (92, 49.3088, 3.14159)
#
# Difference: (1.7527737607690312, -0.99093380138914, 0.3352942740389176)
# Timestamp = 20, Vehicle = DU.1
# Estimation: (91.4812, 91.2642, 3.05294)
#
# GroundTruth: (92, 90.4462, 3.14159)
#
# Difference: (0.5188334630551026, -0.8179932568717874, -0.08865384393391075)
# Timestamp = 20, Vehicle = DU.2
# Estimation: (90.3211, 116.817, 2.95358)
#
# GroundTruth: (92, 127.93, 3.14159)
#
# Difference: (1.6788868699148765, 11.113432312278277, -0.18801134442377834)
# Timestamp = 20, Vehicle = DU.3
# Estimation: (91.7774, 189.92, 2.96726)
#
# GroundTruth: (92, 182.482, 3.14159)
#
# Difference: (0.22261421708228113, -7.437822998534784, -0.17433666408249815)
# Timestamp = 20, Vehicle = LR.0
# Estimation: (77.6315, 90.8, 1.46732)
#
# GroundTruth: (75.177, 92, 1.5708)
#
# Difference: (-2.4545211564166465, 1.1999986465758496, -0.10348115923241348)
# Timestamp = 20, Vehicle = LR.1
# Estimation: (31.3327, 93.8386, 1.82073)
#
# GroundTruth: (26.1043, 92, 1.5708)
#
# Difference: (-5.228402734647602, -1.8386169547156612, 0.24993434688873592)
# Timestamp = 20, Vehicle = RL.0
# Estimation: (186.124, 97.3633, -1.55834)
#
# GroundTruth: (192.346, 108, -1.5708)
#
# Difference: (6.221935519743681, 10.636695122455535, 0.012453569269631603)
# Timestamp = 20, Vehicle = UD.0
# Estimation: (108.796, 32.8293, -0.25463)
#
# GroundTruth: (108, 43.3206, 0)
#
# Difference: (-0.7957856555928942, 10.491360774206314, -0.2546299484482378)
# Timestamp = 20, Vehicle = UD.1
# Estimation: (117.66, 17.5879, -0.0644884)
#
# GroundTruth: (108, 9.26263, 0)
#
# Difference: (-9.659775948239215, -8.3252338267064, -0.06448837318462361)
#
#
# end time 20
#
# time: 21
# current time: 21.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1')
# departed vehicle list: ('DU.4',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:39.7442245925002, angle:3.141592653589793
# DU.1: x:92.0, y:82.29429021507401, angle:3.141592653589793
# DU.2: x:92.0, y:118.7869906066757, angle:3.141592653589793
# DU.3: x:92.0, y:174.72089273720047, angle:3.141592653589793
# DU.4: x:92.0, y:194.9, angle:3.141592653589793
# LR.0: x:81.64887767843557, y:92.0, angle:1.5707963267948966
# LR.1: x:33.95499936745183, y:92.0, angle:1.5707963267948966
# RL.0: x:187.26584664499387, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:52.36618124555801, angle:0.0
# UD.1: x:108.0, y:14.574950293055737, angle:0.0
#
#
# after optimization:
# Timestamp = 21, Vehicle = DU.0
# Estimation: (86.7567, 37.1647, 2.47144)
#
# GroundTruth: (92, 39.7442, 3.14159)
#
# Difference: (5.243309318673113, 2.579567924312009, -0.6701491637025588)
# Timestamp = 21, Vehicle = DU.1
# Estimation: (97.3429, 72.9895, -3.06868)
#
# GroundTruth: (92, 82.2943, 3.14159)
#
# Difference: (-5.342870538676962, 9.304829327978851, 0.07290848921824238)
# Timestamp = 21, Vehicle = DU.2
# Estimation: (94.7755, 112.587, -2.63752)
#
# GroundTruth: (92, 118.787, 3.14159)
#
# Difference: (-2.7754872546332194, 6.199799476805552, 0.5040738537800747)
# Timestamp = 21, Vehicle = DU.3
# Estimation: (91.9921, 171.418, -2.77684)
#
# GroundTruth: (92, 174.721, 3.14159)
#
# Difference: (0.007901691631388985, 3.303349541031025, 0.36475728410486374)
# Timestamp = 21, Vehicle = DU.4
# Estimation: (100.42, 200.701, -2.67032)
#
# GroundTruth: (92, 194.9, 3.14159)
#
# Difference: (-8.420299929341184, -5.800850524911368, 0.47127618479244415)
# Timestamp = 21, Vehicle = LR.0
# Estimation: (78.1007, 90.3233, 1.39853)
#
# GroundTruth: (81.6489, 92, 1.5708)
#
# Difference: (3.548202755710051, 1.6767214583842502, -0.1722670480939016)
# Timestamp = 21, Vehicle = LR.1
# Estimation: (28.0038, 88.7081, 1.75922)
#
# GroundTruth: (33.955, 92, 1.5708)
#
# Difference: (5.951205096266275, 3.2918981564651233, 0.1884242638839408)
# Timestamp = 21, Vehicle = RL.0
# Estimation: (191.03, 112.269, -1.82082)
#
# GroundTruth: (187.266, 108, -1.5708)
#
# Difference: (-3.76389867803897, -4.268714240090105, -0.2500188944953377)
# Timestamp = 21, Vehicle = UD.0
# Estimation: (113.14, 55.8734, 0.0597727)
#
# GroundTruth: (108, 52.3662, 0)
#
# Difference: (-5.140007212328655, -3.5071976898791206, 0.05977270012579502)
# Timestamp = 21, Vehicle = UD.1
# Estimation: (111.68, 11.7882, 0.288437)
#
# GroundTruth: (108, 14.575, 0)
#
# Difference: (-3.680412025901248, 2.786730976111196, 0.288436913771568)
#
#
# end time 21
#
# time: 22
# current time: 22.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:30.019542255659914, angle:3.141592653589793
# DU.1: x:92.0, y:73.77058248645643, angle:3.141592653589793
# DU.2: x:92.0, y:108.86006127736941, angle:3.141592653589793
# DU.3: x:92.0, y:165.46634831621776, angle:3.141592653589793
# DU.4: x:92.0, y:192.56440883474426, angle:3.141592653589793
# LR.0: x:84.1896310342718, y:92.0, angle:1.5707963267948966
# LR.1: x:40.991880301784136, y:92.0, angle:1.5707963267948966
# RL.0: x:180.19358085615096, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:62.355201410681545, angle:0.0
# UD.1: x:108.0, y:21.343132322235032, angle:0.0
#
#
# after optimization:
# Timestamp = 22, Vehicle = DU.0
# Estimation: (94.8892, 31.3672, 2.49116)
#
# GroundTruth: (92, 30.0195, 3.14159)
#
# Difference: (-2.8892223314586545, -1.3476120510854521, -0.6504361743175574)
# Timestamp = 22, Vehicle = DU.1
# Estimation: (89.9262, 79.329, 2.94247)
#
# GroundTruth: (92, 73.7706, 3.14159)
#
# Difference: (2.073820789488252, -5.55840635403878, -0.19912207748896119)
# Timestamp = 22, Vehicle = DU.2
# Estimation: (87.5276, 99.7205, -2.6615)
#
# GroundTruth: (92, 108.86, 3.14159)
#
# Difference: (4.4724396697108375, 9.13957997682678, 0.4800969159703785)
# Timestamp = 22, Vehicle = DU.3
# Estimation: (94.2571, 162.083, 2.52638)
#
# GroundTruth: (92, 165.466, 3.14159)
#
# Difference: (-2.2571401069225914, 3.3835067620342727, -0.6152155099774008)
# Timestamp = 22, Vehicle = DU.4
# Estimation: (97.6544, 192.82, 2.53525)
#
# GroundTruth: (92, 192.564, 3.14159)
#
# Difference: (-5.654352670193447, -0.2555007838130905, -0.6063391490213761)
# Timestamp = 22, Vehicle = LR.0
# Estimation: (82.038, 90.9382, 1.50785)
#
# GroundTruth: (84.1896, 92, 1.5708)
#
# Difference: (2.151587772851869, 1.0618221001112431, -0.06294390598669439)
# Timestamp = 22, Vehicle = LR.1
# Estimation: (39.7367, 99.3209, 1.57502)
#
# GroundTruth: (40.9919, 92, 1.5708)
#
# Difference: (1.2552161430036506, -7.320935106179732, 0.004227794515527775)
# Timestamp = 22, Vehicle = RL.0
# Estimation: (183.572, 111.901, -1.54327)
#
# GroundTruth: (180.194, 108, -1.5708)
#
# Difference: (-3.3786574887420215, -3.9010753411470347, 0.027524947144360084)
# Timestamp = 22, Vehicle = UD.0
# Estimation: (107.987, 71.839, 0.38643)
#
# GroundTruth: (108, 62.3552, 0)
#
# Difference: (0.012724044832111758, -9.48384707130542, 0.38643030125010647)
# Timestamp = 22, Vehicle = UD.1
# Estimation: (110.43, 27.932, 0.579865)
#
# GroundTruth: (108, 21.3431, 0)
#
# Difference: (-2.430336690351808, -6.588835325330539, 0.5798654455830503)
#
#
# end time 22
#
# time: 23
# current time: 23.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2')
# departed vehicle list: ('UD.2',)
# arrived vehicle list: ()
# DU.0: x:92.0, y:19.719135372371298, angle:3.141592653589793
# DU.1: x:92.0, y:64.73345495949634, angle:3.141592653589793
# DU.2: x:92.0, y:99.1456606890736, angle:3.141592653589793
# DU.3: x:92.0, y:155.85521615188978, angle:3.141592653589793
# DU.4: x:92.0, y:188.08932136155198, angle:3.141592653589793
# LR.0: x:84.84336673733868, y:92.0, angle:1.5707963267948966
# LR.1: x:48.06091738655526, y:92.0, angle:1.5707963267948966
# RL.0: x:171.2333591265108, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:72.21528032432785, angle:0.0
# UD.1: x:108.0, y:29.97026083004611, angle:0.0
# UD.2: x:108.0, y:5.1, angle:0.0
#
#
# after optimization:
# Timestamp = 23, Vehicle = DU.0
# Estimation: (94.1686, 21.5171, -2.86627)
#
# GroundTruth: (92, 19.7191, 3.14159)
#
# Difference: (-2.1685503509583555, -1.7979825829347362, 0.2753205581639108)
# Timestamp = 23, Vehicle = DU.1
# Estimation: (95.0818, 69.7616, 2.59773)
#
# GroundTruth: (92, 64.7335, 3.14159)
#
# Difference: (-3.0818031876983127, -5.028173967619111, -0.5438650136569951)
# Timestamp = 23, Vehicle = DU.2
# Estimation: (95.2776, 93.5262, -2.63604)
#
# GroundTruth: (92, 99.1457, 3.14159)
#
# Difference: (-3.277599639011356, 5.619502449643974, 0.5055523573922236)
# Timestamp = 23, Vehicle = DU.3
# Estimation: (86.7267, 162.812, 3.0811)
#
# GroundTruth: (92, 155.855, 3.14159)
#
# Difference: (5.273307244011278, -6.956300844826501, -0.06049598050000336)
# Timestamp = 23, Vehicle = DU.4
# Estimation: (96.5191, 185.945, -2.83882)
#
# GroundTruth: (92, 188.089, 3.14159)
#
# Difference: (-4.519105525093792, 2.144070466699759, 0.30277393121127505)
# Timestamp = 23, Vehicle = LR.0
# Estimation: (65.4447, 82.2957, 1.92294)
#
# GroundTruth: (84.8434, 92, 1.5708)
#
# Difference: (19.39870650330397, 9.704294839252796, 0.3521441339510419)
# Timestamp = 23, Vehicle = LR.1
# Estimation: (44.0009, 89.4095, 1.67042)
#
# GroundTruth: (48.0609, 92, 1.5708)
#
# Difference: (4.060041412249923, 2.5905472476279385, 0.09962185797018032)
# Timestamp = 23, Vehicle = RL.0
# Estimation: (171.065, 105.849, -1.68648)
#
# GroundTruth: (171.233, 108, -1.5708)
#
# Difference: (0.16838258962152963, 2.1514684657326626, -0.11568833117597127)
# Timestamp = 23, Vehicle = UD.0
# Estimation: (101.674, 72.9187, 0.422273)
#
# GroundTruth: (108, 72.2153, 0)
#
# Difference: (6.3263308211636655, -0.7033697528822103, 0.422273068529259)
# Timestamp = 23, Vehicle = UD.1
# Estimation: (108.152, 17.2421, -0.145459)
#
# GroundTruth: (108, 29.9703, 0)
#
# Difference: (-0.1516929177039259, 12.72817927497211, -0.14545941632208173)
# Timestamp = 23, Vehicle = UD.2
# Estimation: (108.175, 12.3696, 0.23097)
#
# GroundTruth: (108, 5.1, 0)
#
# Difference: (-0.17471794681870279, -7.2695879080440875, 0.2309702676494352)
#
#
# end time 23
#
# time: 24
# current time: 24.0
# current vehicle list: ('DU.0', 'DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.0: x:92.0, y:9.585476063032075, angle:3.141592653589793
# DU.1: x:92.0, y:56.02359245083082, angle:3.141592653589793
# DU.2: x:92.0, y:90.05287424298241, angle:3.141592653589793
# DU.3: x:92.0, y:146.30146142573915, angle:3.141592653589793
# DU.4: x:92.0, y:181.32780616027304, angle:3.141592653589793
# LR.0: x:85.20245637927033, y:92.0, angle:1.5707963267948966
# LR.1: x:55.1762079357672, y:92.0, angle:1.5707963267948966
# RL.0: x:162.04997587550292, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:82.40717067086382, angle:0.0
# UD.1: x:108.0, y:37.654444678960296, angle:0.0
# UD.2: x:108.0, y:7.012097218306735, angle:0.0
#
#
# after optimization:
# Timestamp = 24, Vehicle = DU.0
# Estimation: (88.2588, 11.633, -2.66318)
#
# GroundTruth: (92, 9.58548, 3.14159)
#
# Difference: (3.7411568636747177, -2.0475569026450238, 0.4784110753969815)
# Timestamp = 24, Vehicle = DU.1
# Estimation: (95.2311, 64.6137, 2.91559)
#
# GroundTruth: (92, 56.0236, 3.14159)
#
# Difference: (-3.231077943595068, -8.590136493440639, -0.2260019333813665)
# Timestamp = 24, Vehicle = DU.2
# Estimation: (85.8929, 88.6198, -2.81441)
#
# GroundTruth: (92, 90.0529, 3.14159)
#
# Difference: (6.10705248272636, 1.4330505322653835, 0.32718563499412123)
# Timestamp = 24, Vehicle = DU.3
# Estimation: (96.1578, 140.127, 2.78326)
#
# GroundTruth: (92, 146.301, 3.14159)
#
# Difference: (-4.1577510791018994, 6.174934804402142, -0.35833641090943896)
# Timestamp = 24, Vehicle = DU.4
# Estimation: (100.922, 175.216, -3.12553)
#
# GroundTruth: (92, 181.328, 3.14159)
#
# Difference: (-8.921510874399672, 6.111814703699963, 0.01606383500247227)
# Timestamp = 24, Vehicle = LR.0
# Estimation: (80.4095, 91.5131, 1.15856)
#
# GroundTruth: (85.2025, 92, 1.5708)
#
# Difference: (4.792939713975272, 0.4869286173609595, -0.4122391620381445)
# Timestamp = 24, Vehicle = LR.1
# Estimation: (55.2192, 90.2799, 1.69504)
#
# GroundTruth: (55.1762, 92, 1.5708)
#
# Difference: (-0.043038616606196456, 1.720085959582505, 0.12424434093082258)
# Timestamp = 24, Vehicle = RL.0
# Estimation: (167.749, 110.281, -1.26804)
#
# GroundTruth: (162.05, 108, -1.5708)
#
# Difference: (-5.69918494329707, -2.2814521602332576, 0.30275765444131036)
# Timestamp = 24, Vehicle = UD.0
# Estimation: (110.944, 73.9554, -0.332109)
#
# GroundTruth: (108, 82.4072, 0)
#
# Difference: (-2.9439776591071904, 8.451762517791323, -0.3321092603518754)
# Timestamp = 24, Vehicle = UD.1
# Estimation: (111.338, 45.4027, 0.487181)
#
# GroundTruth: (108, 37.6544, 0)
#
# Difference: (-3.338367631603276, -7.74829585680115, 0.4871809510684422)
# Timestamp = 24, Vehicle = UD.2
# Estimation: (107.911, 5.61511, -0.469628)
#
# GroundTruth: (108, 7.0121, 0)
#
# Difference: (0.08858860747116637, 1.396987197531871, -0.4696284646246201)
#
#
# end time 24
#
# time: 25
# current time: 25.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2')
# departed vehicle list: ()
# arrived vehicle list: ('DU.0',)
# DU.1: x:92.0, y:46.794244719570486, angle:3.141592653589793
# DU.2: x:92.0, y:80.04869506532245, angle:3.141592653589793
# DU.3: x:92.0, y:136.15970962383616, angle:3.141592653589793
# DU.4: x:92.0, y:173.13640649907595, angle:3.141592653589793
# LR.0: x:85.38041738525415, y:92.0, angle:1.5707963267948966
# LR.1: x:62.35877365915081, y:92.0, angle:1.5707963267948966
# RL.0: x:153.2649266208664, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:91.564071307853, angle:0.0
# UD.1: x:108.0, y:45.340314173980964, angle:0.0
# UD.2: x:108.0, y:10.992936124303379, angle:0.0
#
#
# after optimization:
# Timestamp = 25, Vehicle = DU.1
# Estimation: (96.8147, 43.8003, 2.89749)
#
# GroundTruth: (92, 46.7942, 3.14159)
#
# Difference: (-4.814691993815089, 2.9939830392532443, -0.24410685676745997)
# Timestamp = 25, Vehicle = DU.2
# Estimation: (91.3039, 89.2395, 3.11707)
#
# GroundTruth: (92, 80.0487, 3.14159)
#
# Difference: (0.6961425969317077, -9.190838214284952, -0.024521147339150683)
# Timestamp = 25, Vehicle = DU.3
# Estimation: (90.0794, 134.275, -3.12371)
#
# GroundTruth: (92, 136.16, 3.14159)
#
# Difference: (1.9206168803002868, 1.8848954525071235, 0.01788046334492336)
# Timestamp = 25, Vehicle = DU.4
# Estimation: (95.8471, 178.545, -2.22207)
#
# GroundTruth: (92, 173.136, 3.14159)
#
# Difference: (-3.84711212799472, -5.408657084772244, 0.9195267139862039)
# Timestamp = 25, Vehicle = LR.0
# Estimation: (80.4756, 94.7146, 1.70954)
#
# GroundTruth: (85.3804, 92, 1.5708)
#
# Difference: (4.904824656148293, -2.7146081014728054, 0.13874625440002572)
# Timestamp = 25, Vehicle = LR.1
# Estimation: (62.5352, 92.496, 1.44086)
#
# GroundTruth: (62.3588, 92, 1.5708)
#
# Difference: (-0.1764214667270778, -0.4959996740435315, -0.12993929142252195)
# Timestamp = 25, Vehicle = RL.0
# Estimation: (150.485, 111.17, -1.20498)
#
# GroundTruth: (153.265, 108, -1.5708)
#
# Difference: (2.779891038645644, -3.1698156634571006, 0.3658199493063051)
# Timestamp = 25, Vehicle = UD.0
# Estimation: (107.291, 84.9032, 0.484051)
#
# GroundTruth: (108, 91.5641, 0)
#
# Difference: (0.7085398718803333, 6.660878630070997, 0.4840509931134032)
# Timestamp = 25, Vehicle = UD.1
# Estimation: (95.8112, 44.9752, 0.0821898)
#
# GroundTruth: (108, 45.3403, 0)
#
# Difference: (12.188790309947223, 0.36510088604527624, 0.08218979879382998)
# Timestamp = 25, Vehicle = UD.2
# Estimation: (111.192, 12.5061, -0.0857899)
#
# GroundTruth: (108, 10.9929, 0)
#
# Difference: (-3.1921936141733767, -1.5131728481508855, -0.08578991340004781)
#
#
# end time 25
#
# time: 26
# current time: 26.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.1: x:92.0, y:37.54475520942383, angle:3.141592653589793
# DU.2: x:92.0, y:70.30267192601755, angle:3.141592653589793
# DU.3: x:92.0, y:126.8079304059293, angle:3.141592653589793
# DU.4: x:92.0, y:165.2044611502639, angle:3.141592653589793
# LR.0: x:85.39567771534593, y:92.0, angle:1.5707963267948966
# LR.1: x:69.60764537163128, y:92.0, angle:1.5707963267948966
# RL.0: x:144.13105268623866, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:100.98184858216686, angle:0.0
# UD.1: x:108.0, y:54.16899883226757, angle:0.0
# UD.2: x:108.0, y:16.741467076097614, angle:0.0
#
#
# after optimization:
# Timestamp = 26, Vehicle = DU.1
# Estimation: (91.9203, 44.639, -3.11952)
#
# GroundTruth: (92, 37.5448, 3.14159)
#
# Difference: (0.07967315478016701, -7.094238812621732, 0.02207314214004223)
# Timestamp = 26, Vehicle = DU.2
# Estimation: (85.3943, 65.3367, -2.94141)
#
# GroundTruth: (92, 70.3027, 3.14159)
#
# Difference: (6.605733087270622, 4.965935517287164, 0.20018675557123308)
# Timestamp = 26, Vehicle = DU.3
# Estimation: (97.9562, 124.727, 2.91912)
#
# GroundTruth: (92, 126.808, 3.14159)
#
# Difference: (-5.956171333180052, 2.0809216893498075, -0.22247298962104634)
# Timestamp = 26, Vehicle = DU.4
# Estimation: (86.2957, 172.51, 2.98393)
#
# GroundTruth: (92, 165.204, 3.14159)
#
# Difference: (5.704253205769163, -7.305680033534827, -0.15766191245900746)
# Timestamp = 26, Vehicle = LR.0
# Estimation: (83.1406, 92.4112, 1.44117)
#
# GroundTruth: (85.3957, 92, 1.5708)
#
# Difference: (2.255117911336285, -0.4111627263567357, -0.12962164314499205)
# Timestamp = 26, Vehicle = LR.1
# Estimation: (65.605, 89.167, 1.25892)
#
# GroundTruth: (69.6076, 92, 1.5708)
#
# Difference: (4.002617313950324, 2.8329944581163886, -0.3118811676531155)
# Timestamp = 26, Vehicle = RL.0
# Estimation: (153.606, 109.654, -2.00329)
#
# GroundTruth: (144.131, 108, -1.5708)
#
# Difference: (-9.475201433755814, -1.6540099085033546, -0.4324901147702854)
# Timestamp = 26, Vehicle = UD.0
# Estimation: (97.0569, 103.191, 0.094996)
#
# GroundTruth: (108, 100.982, 0)
#
# Difference: (10.943120655689398, -2.209259198991546, 0.09499597630912975)
# Timestamp = 26, Vehicle = UD.1
# Estimation: (111.189, 59.2678, 0.0399753)
#
# GroundTruth: (108, 54.169, 0)
#
# Difference: (-3.1885988906537506, -5.098803433579107, 0.03997533553977413)
# Timestamp = 26, Vehicle = UD.2
# Estimation: (102.736, 19.0701, -0.715815)
#
# GroundTruth: (108, 16.7415, 0)
#
# Difference: (5.264369398122369, -2.328592539231039, -0.7158153050942446)
#
#
# end time 26
#
# time: 27
# current time: 27.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3')
# departed vehicle list: ('UD.3',)
# arrived vehicle list: ()
# DU.1: x:92.0, y:28.96657053088444, angle:3.141592653589793
# DU.2: x:92.0, y:60.58879608709575, angle:3.141592653589793
# DU.3: x:92.0, y:117.06277312873581, angle:3.141592653589793
# DU.4: x:92.0, y:157.69920745584625, angle:3.141592653589793
# LR.0: x:85.39803027015266, y:92.0, angle:1.5707963267948966
# LR.1: x:75.93102829467888, y:95.2, angle:1.5707963267948966
# RL.0: x:134.98908766071196, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:110.8774592701161, angle:0.0
# UD.1: x:108.0, y:62.15857354041403, angle:0.0
# UD.2: x:108.0, y:24.193332368112166, angle:0.0
# UD.3: x:108.0, y:5.1, angle:0.0
#
#
# after optimization:
# Timestamp = 27, Vehicle = DU.1
# Estimation: (88.7389, 23.4468, 2.37958)
#
# GroundTruth: (92, 28.9666, 3.14159)
#
# Difference: (3.2610810470966243, 5.519737329305581, -0.7620154767389851)
# Timestamp = 27, Vehicle = DU.2
# Estimation: (86.6994, 70.7981, -3.0251)
#
# GroundTruth: (92, 60.5888, 3.14159)
#
# Difference: (5.3005885634042755, -10.209268457874764, 0.11648951479727217)
# Timestamp = 27, Vehicle = DU.3
# Estimation: (98.6087, 111.8, 2.93498)
#
# GroundTruth: (92, 117.063, 3.14159)
#
# Difference: (-6.608702621749913, 5.262987039132923, -0.20661531087312732)
# Timestamp = 27, Vehicle = DU.4
# Estimation: (87.9235, 164.798, 3.11464)
#
# GroundTruth: (92, 157.699, 3.14159)
#
# Difference: (4.076542501165179, -7.0988852507324225, -0.02695366725031223)
# Timestamp = 27, Vehicle = LR.0
# Estimation: (83.4073, 101.612, 2.22796)
#
# GroundTruth: (85.398, 92, 1.5708)
#
# Difference: (1.9907344820993842, -9.612008031564045, 0.6571619488330307)
# Timestamp = 27, Vehicle = LR.1
# Estimation: (63.3169, 92.5435, 1.57539)
#
# GroundTruth: (75.931, 95.2, 1.5708)
#
# Difference: (12.614140589529867, 2.6565012211790986, 0.004594221194295964)
# Timestamp = 27, Vehicle = RL.0
# Estimation: (137.984, 108.726, -1.33113)
#
# GroundTruth: (134.989, 108, -1.5708)
#
# Difference: (-2.9945200110900316, -0.7258240114130672, 0.2396680163667682)
# Timestamp = 27, Vehicle = UD.0
# Estimation: (106.543, 113.335, 0.167849)
#
# GroundTruth: (108, 110.877, 0)
#
# Difference: (1.4570856465155089, -2.457128543412466, 0.16784946995326003)
# Timestamp = 27, Vehicle = UD.1
# Estimation: (110.435, 62.643, 0.0274839)
#
# GroundTruth: (108, 62.1586, 0)
#
# Difference: (-2.4353001864126753, -0.4844426547242051, 0.027483871388142816)
# Timestamp = 27, Vehicle = UD.2
# Estimation: (109.102, 26.1106, 0.246155)
#
# GroundTruth: (108, 24.1933, 0)
#
# Difference: (-1.1015631915233826, -1.9172944281667306, 0.24615484148250769)
# Timestamp = 27, Vehicle = UD.3
# Estimation: (100.649, 8.13202, 0.800658)
#
# GroundTruth: (108, 5.1, 0)
#
# Difference: (7.351185445106566, -3.0320197215191858, 0.8006584889323145)
#
#
# end time 27
#
# time: 28
# current time: 28.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.1: x:92.0, y:20.665154350956698, angle:3.141592653589793
# DU.2: x:92.0, y:51.571948209781034, angle:3.141592653589793
# DU.3: x:92.0, y:107.54152724707161, angle:3.141592653589793
# DU.4: x:92.0, y:149.27041402581895, angle:3.141592653589793
# LR.0: x:85.39896226949338, y:92.0, angle:1.5707963267948966
# LR.1: x:82.29643736097502, y:95.2, angle:1.5707963267948966
# RL.0: x:125.99426813140093, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:120.03145099103237, angle:0.0
# UD.1: x:108.0, y:70.47002934956156, angle:0.0
# UD.2: x:108.0, y:33.938195400033145, angle:0.0
# UD.3: x:108.0, y:6.690261032572016, angle:0.0
#
#
# after optimization:
# Timestamp = 28, Vehicle = DU.1
# Estimation: (95.4274, 25.6152, 2.97463)
#
# GroundTruth: (92, 20.6652, 3.14159)
#
# Difference: (-3.4273918268390275, -4.950049840939517, -0.1669671118188692)
# Timestamp = 28, Vehicle = DU.2
# Estimation: (90.6951, 45.4826, -2.88995)
#
# GroundTruth: (92, 51.5719, 3.14159)
#
# Difference: (1.3049238618343253, 6.089378570180202, 0.2516466736422836)
# Timestamp = 28, Vehicle = DU.3
# Estimation: (89.2215, 109.041, 2.78881)
#
# GroundTruth: (92, 107.542, 3.14159)
#
# Difference: (2.778541317424242, -1.4996444947112053, -0.35278368208649413)
# Timestamp = 28, Vehicle = DU.4
# Estimation: (94.7946, 150.904, -3.02368)
#
# GroundTruth: (92, 149.27, 3.14159)
#
# Difference: (-2.7945770902315843, -1.6332981829801838, 0.11791135969502782)
# Timestamp = 28, Vehicle = LR.0
# Estimation: (93.1434, 98.827, 2.26694)
#
# GroundTruth: (85.399, 92, 1.5708)
#
# Difference: (-7.744426663897556, -6.8270368397194545, 0.6961452991572359)
# Timestamp = 28, Vehicle = LR.1
# Estimation: (85.5764, 97.4256, 1.59387)
#
# GroundTruth: (82.2964, 95.2, 1.5708)
#
# Difference: (-3.279971419485264, -2.2256170525723604, 0.023075140339223088)
# Timestamp = 28, Vehicle = RL.0
# Estimation: (127.3, 108.466, -1.82719)
#
# GroundTruth: (125.994, 108, -1.5708)
#
# Difference: (-1.3060868263217316, -0.46563340511713136, -0.2563901768636694)
# Timestamp = 28, Vehicle = UD.0
# Estimation: (108.494, 113.321, 0.160051)
#
# GroundTruth: (108, 120.031, 0)
#
# Difference: (-0.4936606954073284, 6.710945843015892, 0.1600505709767131)
# Timestamp = 28, Vehicle = UD.1
# Estimation: (99.4831, 74.4757, -0.398539)
#
# GroundTruth: (108, 70.47, 0)
#
# Difference: (8.516907396729437, -4.005659557025169, -0.39853945042240446)
# Timestamp = 28, Vehicle = UD.2
# Estimation: (106.11, 34.9672, 0.187619)
#
# GroundTruth: (108, 33.9382, 0)
#
# Difference: (1.8904129491081676, -1.02897283801628, 0.18761945335046662)
# Timestamp = 28, Vehicle = UD.3
# Estimation: (117.323, 3.69172, 0.650076)
#
# GroundTruth: (108, 6.69026, 0)
#
# Difference: (-9.322634938776488, 2.998537388381246, 0.6500763599761709)
#
#
# end time 28
#
# time: 29
# current time: 29.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3')
# departed vehicle list: ()
# arrived vehicle list: ()
# DU.1: x:92.0, y:11.926708979573135, angle:3.141592653589793
# DU.2: x:92.0, y:42.74597599993962, angle:3.141592653589793
# DU.3: x:92.0, y:97.96250592534037, angle:3.141592653589793
# DU.4: x:92.0, y:141.37689571803554, angle:3.141592653589793
# LR.0: x:85.39896226949338, y:92.0, angle:1.5707963267948966
# LR.1: x:85.00585085384176, y:95.2, angle:1.5707963267948966
# RL.0: x:118.41119013884081, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:129.46207568112317, angle:0.0
# UD.1: x:108.0, y:78.68319061481508, angle:0.0
# UD.2: x:108.0, y:44.52632498028656, angle:0.0
# UD.3: x:108.0, y:10.201473211380652, angle:0.0
#
#
# after optimization:
# Timestamp = 29, Vehicle = DU.1
# Estimation: (95.5347, 10.0427, -2.94256)
#
# GroundTruth: (92, 11.9267, 3.14159)
#
# Difference: (-3.5346636116254047, 1.8840440158831449, 0.19903598135098605)
# Timestamp = 29, Vehicle = DU.2
# Estimation: (93.2013, 47.3397, -2.75704)
#
# GroundTruth: (92, 42.746, 3.14159)
#
# Difference: (-1.2013119520222375, -4.593756086197132, 0.3845479837497967)
# Timestamp = 29, Vehicle = DU.3
# Estimation: (96.916, 98.2062, 3.01253)
#
# GroundTruth: (92, 97.9625, 3.14159)
#
# Difference: (-4.916041453585493, -0.24370978961842127, -0.12906128632568592)
# Timestamp = 29, Vehicle = DU.4
# Estimation: (84.2222, 136.782, 2.80161)
#
# GroundTruth: (92, 141.377, 3.14159)
#
# Difference: (7.777765130143948, 4.595342123563086, -0.3399830335116131)
# Timestamp = 29, Vehicle = LR.0
# Estimation: (79.7415, 96.2557, 1.99506)
#
# GroundTruth: (85.399, 92, 1.5708)
#
# Difference: (5.657481558578141, -4.255679071795456, 0.42426619481274863)
# Timestamp = 29, Vehicle = LR.1
# Estimation: (75.7659, 98.9259, 1.61135)
#
# GroundTruth: (85.0059, 95.2, 1.5708)
#
# Difference: (9.2399632702667, -3.725909884267466, 0.040556352085276755)
# Timestamp = 29, Vehicle = RL.0
# Estimation: (113.784, 102.418, -1.59343)
#
# GroundTruth: (118.411, 108, -1.5708)
#
# Difference: (4.627541570545688, 5.582442233279906, -0.022636741185910872)
# Timestamp = 29, Vehicle = UD.0
# Estimation: (102.716, 125.979, 0.403922)
#
# GroundTruth: (108, 129.462, 0)
#
# Difference: (5.284393432215126, 3.482998506426185, 0.40392199677495444)
# Timestamp = 29, Vehicle = UD.1
# Estimation: (107.712, 81.3738, -0.172264)
#
# GroundTruth: (108, 78.6832, 0)
#
# Difference: (0.28812336018876294, -2.690606387407314, -0.17226364726798304)
# Timestamp = 29, Vehicle = UD.2
# Estimation: (107, 41.2441, 0.0874704)
#
# GroundTruth: (108, 44.5263, 0)
#
# Difference: (1.0001014906466992, 3.2822567628597312, 0.0874704029360375)
# Timestamp = 29, Vehicle = UD.3
# Estimation: (104.148, -2.12585, 0.5032)
#
# GroundTruth: (108, 10.2015, 0)
#
# Difference: (3.8524368155923128, 12.327321508818855, 0.5032003180620548)
#
#
# end time 29
#
# time: 30
# current time: 30.0
# current vehicle list: ('DU.1', 'DU.2', 'DU.3', 'DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.0', 'UD.1', 'UD.2', 'UD.3', 'UD.4')
# departed vehicle list: ('UD.4',)
# arrived vehicle list: ()
# DU.1: x:92.0, y:3.437001212849566, angle:3.141592653589793
# DU.2: x:92.0, y:32.651848813208716, angle:3.141592653589793
# DU.3: x:92.0, y:88.09012522430176, angle:3.141592653589793
# DU.4: x:92.0, y:133.08936935739084, angle:3.141592653589793
# LR.0: x:85.39896226949338, y:92.0, angle:1.5707963267948966
# LR.1: x:85.20722344286544, y:95.2, angle:1.5707963267948966
# RL.0: x:115.00176176803558, y:108.0, angle:4.71238898038469
# UD.0: x:108.0, y:138.66952133013194, angle:0.0
# UD.1: x:108.0, y:87.2397454244091, angle:0.0
# UD.2: x:108.0, y:54.3039096483023, angle:0.0
# UD.3: x:108.0, y:15.967616644315418, angle:0.0
# UD.4: x:108.0, y:5.1, angle:0.0
#
#
# after optimization:
# Timestamp = 30, Vehicle = DU.1
# Estimation: (88.9588, 4.84285, -2.99505)
#
# GroundTruth: (92, 3.437, 3.14159)
#
# Difference: (3.0412410159970307, -1.4058522265346882, 0.1465388901670923)
# Timestamp = 30, Vehicle = DU.2
# Estimation: (92.4393, 32.7874, -3.04265)
#
# GroundTruth: (92, 32.6518, 3.14159)
#
# Difference: (-0.4392604713459747, -0.13551145719651458, 0.0989378366878384)
# Timestamp = 30, Vehicle = DU.3
# Estimation: (91.1285, 87.7222, -3.03849)
#
# GroundTruth: (92, 88.0901, 3.14159)
#
# Difference: (0.8714809584377576, 0.36789200106524333, 0.1030984484900045)
# Timestamp = 30, Vehicle = DU.4
# Estimation: (103.8, 132.773, -3.12873)
#
# GroundTruth: (92, 133.089, 3.14159)
#
# Difference: (-11.800058795857737, 0.31602871718442316, 0.012865609156560416)
# Timestamp = 30, Vehicle = LR.0
# Estimation: (86.5543, 94.2183, 1.15682)
#
# GroundTruth: (85.399, 92, 1.5708)
#
# Difference: (-1.1553841227715367, -2.2183069029749873, -0.41398091663901865)
# Timestamp = 30, Vehicle = LR.1
# Estimation: (78.1955, 96.7782, 1.83023)
#
# GroundTruth: (85.2072, 95.2, 1.5708)
#
# Difference: (7.011702151831912, -1.5781523528169856, 0.25943026042428596)
# Timestamp = 30, Vehicle = RL.0
# Estimation: (113.833, 100.958, -1.36845)
#
# GroundTruth: (115.002, 108, -1.5708)
#
# Difference: (1.1682917468775713, 7.04176154197674, 0.20234991913746214)
# Timestamp = 30, Vehicle = UD.0
# Estimation: (105.42, 135.285, 0.0105641)
#
# GroundTruth: (108, 138.67, 0)
#
# Difference: (2.5801373628609383, 3.3847637509775836, 0.010564129176172232)
# Timestamp = 30, Vehicle = UD.1
# Estimation: (108.09, 97.6594, -0.29264)
#
# GroundTruth: (108, 87.2397, 0)
#
# Difference: (-0.09027255285963065, -10.419608347096244, -0.29263998470011693)
# Timestamp = 30, Vehicle = UD.2
# Estimation: (113.713, 51.972, 0.421461)
#
# GroundTruth: (108, 54.3039, 0)
#
# ...
#
# Difference: (3.3721220772311113, 4.349929416891882, -0.16668271685686142)
# Timestamp = 45, Vehicle = UD.4
# Estimation: (116.546, 132.142, 0.316639)
#
# GroundTruth: (108, 132.677, 0)
#
# Difference: (-8.54561508269812, 0.5345337621536999, 0.3166390731648961)
#
#
# end time 45
#
# time: 46
# current time: 46.0
# current vehicle list: ('DU.4', 'LR.0', 'LR.1', 'RL.0', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('UD.2',)
# DU.4: x:92.0, y:5.438440086587008, angle:3.141592653589793
# LR.0: x:87.1853990315022, y:92.0, angle:1.5707963267948966
# LR.1: x:87.58094054169224, y:95.2, angle:1.5707963267948966
# RL.0: x:112.59724669841076, y:108.0, angle:4.71238898038469
# UD.3: x:108.0, y:167.78403883774325, angle:0.0
# UD.4: x:108.0, y:142.8883709409741, angle:0.0
#
#
# after optimization:
# Timestamp = 46, Vehicle = DU.4
# Estimation: (87.302, 8.04186, 2.45885)
#
# GroundTruth: (92, 5.43844, 3.14159)
#
# Difference: (4.697953508245831, -2.6034188629512087, -0.6827390618582005)
# Timestamp = 46, Vehicle = LR.0
# Estimation: (93.2558, 93.703, 1.62907)
#
# GroundTruth: (87.1854, 92, 1.5708)
#
# Difference: (-6.070406538544205, -1.7030048184807498, 0.05827826518583511)
# Timestamp = 46, Vehicle = LR.1
# Estimation: (95.586, 93.8792, 2.15453)
#
# GroundTruth: (87.5809, 95.2, 1.5708)
#
# Difference: (-8.005101134099348, 1.3207788975804817, 0.5837368487141432)
# Timestamp = 46, Vehicle = RL.0
# Estimation: (116.025, 109.563, -1.9792)
#
# GroundTruth: (112.597, 108, -1.5708)
#
# Difference: (-3.427427560477625, -1.5627250952772869, -0.40840344692129066)
# Timestamp = 46, Vehicle = UD.3
# Estimation: (105.214, 167.519, -0.17636)
#
# GroundTruth: (108, 167.784, 0)
#
# Difference: (2.7862031730121686, 0.26480562167427024, -0.17635999488196805)
# Timestamp = 46, Vehicle = UD.4
# Estimation: (111.779, 132.994, 0.178044)
#
# GroundTruth: (108, 142.888, 0)
#
# Difference: (-3.7788987528342233, 9.894842023534551, 0.17804440049333056)
#
#
# end time 46
#
# time: 47
# current time: 47.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('DU.4',)
# LR.0: x:90.32741915688663, y:92.0, angle:1.5707963267948966
# LR.1: x:91.42833328779989, y:95.2, angle:1.5707963267948966
# RL.0: x:108.10074112294666, y:108.0, angle:4.71238898038469
# UD.3: x:108.0, y:176.91365724714967, angle:0.0
# UD.4: x:108.0, y:152.48279899331246, angle:0.0
#
#
# after optimization:
# Timestamp = 47, Vehicle = LR.0
# Estimation: (87.6768, 94.9739, 0.911512)
#
# GroundTruth: (90.3274, 92, 1.5708)
#
# Difference: (2.6506500967366122, -2.973871406098823, -0.6592839006225378)
# Timestamp = 47, Vehicle = LR.1
# Estimation: (87.235, 97.5306, 1.30056)
#
# GroundTruth: (91.4283, 95.2, 1.5708)
#
# Difference: (4.193291584713322, -2.3306376115614427, -0.27023268988072885)
# Timestamp = 47, Vehicle = RL.0
# Estimation: (107.288, 111.229, -1.57465)
#
# GroundTruth: (108.101, 108, -1.5708)
#
# Difference: (0.813099773769224, -3.228814060336134, -0.00385173166626836)
# Timestamp = 47, Vehicle = UD.3
# Estimation: (109.947, 175.554, 0.0163816)
#
# GroundTruth: (108, 176.914, 0)
#
# Difference: (-1.9473493630211038, 1.3601245022155979, 0.016381569537341396)
# Timestamp = 47, Vehicle = UD.4
# Estimation: (107.131, 155.031, -0.125511)
#
# GroundTruth: (108, 152.483, 0)
#
# Difference: (0.8692471445275345, -2.54827851000195, -0.12551123210301568)
#
#
# end time 47
#
# time: 48
# current time: 48.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:94.97574011807144, y:92.0, angle:1.5707963267948966
# LR.1: x:97.64009766792616, y:95.2, angle:1.5707963267948966
# RL.0: x:101.74105135084088, y:108.0, angle:4.71238898038469
# UD.3: x:108.0, y:186.2208396343098, angle:0.0
# UD.4: x:108.0, y:162.0710190806857, angle:0.0
#
#
# after optimization:
# Timestamp = 48, Vehicle = LR.0
# Estimation: (88.2151, 91.9594, 1.54198)
#
# GroundTruth: (94.9757, 92, 1.5708)
#
# Difference: (6.760603354866461, 0.040602555605360635, -0.02881916998791251)
# Timestamp = 48, Vehicle = LR.1
# Estimation: (100.531, 100.288, 1.26567)
#
# GroundTruth: (97.6401, 95.2, 1.5708)
#
# Difference: (-2.8910213124374167, -5.087795870252393, -0.3051307303589235)
# Timestamp = 48, Vehicle = RL.0
# Estimation: (90.1049, 114.013, -1.14085)
#
# GroundTruth: (101.741, 108, -1.5708)
#
# Difference: (11.636171120415696, -6.013368272631396, 0.4299413631849059)
# Timestamp = 48, Vehicle = UD.3
# Estimation: (108.857, 195.118, 0.0265324)
#
# GroundTruth: (108, 186.221, 0)
#
# Difference: (-0.8574165081152074, -8.897087915946315, 0.026532418584901827)
# Timestamp = 48, Vehicle = UD.4
# Estimation: (109.704, 155.06, -0.378295)
#
# GroundTruth: (108, 162.071, 0)
#
# Difference: (-1.703528116564513, 7.0112437913163035, -0.37829489068238337)
#
#
# end time 48
#
# time: 49
# current time: 49.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.3', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:101.08212265931348, y:92.0, angle:1.5707963267948966
# LR.1: x:105.9290957314409, y:95.2, angle:1.5707963267948966
# RL.0: x:92.83245765602175, y:108.0, angle:4.71238898038469
# UD.3: x:108.0, y:196.40370089653445, angle:0.0
# UD.4: x:108.0, y:171.616639892211, angle:0.0
#
#
# after optimization:
# Timestamp = 49, Vehicle = LR.0
# Estimation: (104.304, 90.0406, 0.996072)
#
# GroundTruth: (101.082, 92, 1.5708)
#
# Difference: (-3.2214023372782066, 1.9594090783660647, -0.5747244501563666)
# Timestamp = 49, Vehicle = LR.1
# Estimation: (105.848, 94.1658, 1.42253)
#
# GroundTruth: (105.929, 95.2, 1.5708)
#
# Difference: (0.08082104630186393, 1.0342368453544566, -0.14826671733203356)
# Timestamp = 49, Vehicle = RL.0
# Estimation: (91.9103, 111.436, -1.42151)
#
# GroundTruth: (92.8325, 108, -1.5708)
#
# Difference: (0.9221491706972813, -3.4357609549464456, 0.14928254122039405)
# Timestamp = 49, Vehicle = UD.3
# Estimation: (99.1629, 196.527, 0.288555)
#
# GroundTruth: (108, 196.404, 0)
#
# Difference: (8.83706889483041, -0.12316426087528498, 0.2885546582861217)
# Timestamp = 49, Vehicle = UD.4
# Estimation: (114.816, 168.642, -0.291089)
#
# GroundTruth: (108, 171.617, 0)
#
# Difference: (-6.81551329396008, 2.97470146174129, -0.2910892136362202)
#
#
# end time 49
#
# time: 50
# current time: 50.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ('UD.3',)
# LR.0: x:109.7395215452211, y:92.0, angle:1.5707963267948966
# LR.1: x:114.07034831768716, y:95.2, angle:1.5707963267948966
# RL.0: x:83.84026176370801, y:108.0, angle:4.71238898038469
# UD.4: x:108.0, y:181.58061256459297, angle:0.0
#
#
# after optimization:
# Timestamp = 50, Vehicle = LR.0
# Estimation: (113.653, 87.8926, 1.79056)
#
# GroundTruth: (109.74, 92, 1.5708)
#
# Difference: (-3.9131540172092656, 4.107434993079906, 0.21975975430702627)
# Timestamp = 50, Vehicle = LR.1
# Estimation: (110.741, 97.7638, 1.35582)
#
# GroundTruth: (114.07, 95.2, 1.5708)
#
# Difference: (3.329002779108677, -2.5637808912710653, -0.21497749122082715)
# Timestamp = 50, Vehicle = RL.0
# Estimation: (82.7997, 106.169, -1.75502)
#
# GroundTruth: (83.8403, 108, -1.5708)
#
# Difference: (1.0405933807662393, 1.8310974854180273, -0.18421980062078783)
# Timestamp = 50, Vehicle = UD.4
# Estimation: (108.045, 183.108, -0.210823)
#
# GroundTruth: (108, 181.581, 0)
#
# Difference: (-0.04494186219770313, -1.527099478059455, -0.2108225338790591)
#
#
# end time 50
#
# time: 51
# current time: 51.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0', 'UD.4')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:120.02363603737405, y:92.0, angle:1.5707963267948966
# LR.1: x:121.29535316417417, y:95.2, angle:1.5707963267948966
# RL.0: x:75.06816383634978, y:108.0, angle:4.71238898038469
# UD.4: x:108.0, y:191.5559449828676, angle:0.0
#
#
# after optimization:
# Timestamp = 51, Vehicle = LR.0
# Estimation: (121.45, 92.149, 1.363)
#
# GroundTruth: (120.024, 92, 1.5708)
#
# Difference: (-1.4258895292971943, -0.1489597833062959, -0.20779616139815663)
# Timestamp = 51, Vehicle = LR.1
# Estimation: (128.365, 95.2727, 1.32975)
#
# GroundTruth: (121.295, 95.2, 1.5708)
#
# Difference: (-7.069651828630668, -0.0726896074347394, -0.2410501571669499)
# Timestamp = 51, Vehicle = RL.0
# Estimation: (74.7386, 106.185, -1.82486)
#
# GroundTruth: (75.0682, 108, -1.5708)
#
# Difference: (0.32955668656622095, 1.814801343812917, -0.2540640724314896)
# Timestamp = 51, Vehicle = UD.4
# Estimation: (106.989, 193.671, -0.246666)
#
# GroundTruth: (108, 191.556, 0)
#
# Difference: (1.0110320758863764, -2.1146310137816897, -0.24666604100464232)
#
#
# end time 51
#
# time: 52
# current time: 52.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ('UD.4',)
# LR.0: x:130.33185711855654, y:92.0, angle:1.5707963267948966
# LR.1: x:129.1867588819706, y:95.2, angle:1.5707963267948966
# RL.0: x:66.85485274269693, y:108.0, angle:4.71238898038469
#
#
# after optimization:
# Timestamp = 52, Vehicle = LR.0
# Estimation: (126.288, 97.7012, 1.41707)
#
# GroundTruth: (130.332, 92, 1.5708)
#
# Difference: (4.043942359710087, -5.701192787975586, -0.1537306751666378)
# Timestamp = 52, Vehicle = LR.1
# Estimation: (134.903, 101.181, 1.50297)
#
# GroundTruth: (129.187, 95.2, 1.5708)
#
# Difference: (-5.716258896490956, -5.98060306268583, -0.06782301769896813)
# Timestamp = 52, Vehicle = RL.0
# Estimation: (66.5145, 106.982, -1.54963)
#
# GroundTruth: (66.8549, 108, -1.5708)
#
# Difference: (0.34032369487577796, 1.0178098223768473, 0.02116642987155052)
#
#
# end time 52
#
# time: 53
# current time: 53.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:141.13676298215557, y:92.0, angle:1.5707963267948966
# LR.1: x:137.34791150004708, y:95.2, angle:1.5707963267948966
# RL.0: x:57.645114427028744, y:108.0, angle:4.71238898038469
#
#
# after optimization:
# Timestamp = 53, Vehicle = LR.0
# Estimation: (135.073, 89.5162, 1.45176)
#
# GroundTruth: (141.137, 92, 1.5708)
#
# Difference: (6.063826943336977, 2.4838497496447474, -0.11903811222151722)
# Timestamp = 53, Vehicle = LR.1
# Estimation: (132.225, 100.003, 1.81268)
#
# GroundTruth: (137.348, 95.2, 1.5708)
#
# Difference: (5.123167853300828, -4.803194630562814, 0.24188568454246737)
# Timestamp = 53, Vehicle = RL.0
# Estimation: (61.224, 106.451, -1.10761)
#
# GroundTruth: (57.6451, 108, -1.5708)
#
# Difference: (-3.5788522966716343, 1.5485406915807118, 0.46318416563622516)
#
#
# end time 53
#
# time: 54
# current time: 54.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:150.7263777005203, y:92.0, angle:1.5707963267948966
# LR.1: x:145.0286066749151, y:95.2, angle:1.5707963267948966
# RL.0: x:48.86183044054854, y:108.0, angle:4.71238898038469
#
#
# after optimization:
# Timestamp = 54, Vehicle = LR.0
# Estimation: (153.176, 91.0981, 1.77237)
#
# GroundTruth: (150.726, 92, 1.5708)
#
# Difference: (-2.4492382036986555, 0.9019352275479946, 0.20157380307019335)
# Timestamp = 54, Vehicle = LR.1
# Estimation: (152.746, 100.827, 1.92571)
#
# GroundTruth: (145.029, 95.2, 1.5708)
#
# Difference: (-7.717664143115485, -5.626764710665341, 0.3549111375834783)
# Timestamp = 54, Vehicle = RL.0
# Estimation: (48.2408, 113.809, -1.35505)
#
# GroundTruth: (48.8618, 108, -1.5708)
#
# Difference: (0.6210674824231432, -5.809115528058356, 0.2157477480547091)
#
#
# end time 54
#
# time: 55
# current time: 55.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:161.15052148888233, y:92.0, angle:1.5707963267948966
# LR.1: x:152.46934090373358, y:95.2, angle:1.5707963267948966
# RL.0: x:39.77303785116883, y:108.0, angle:4.71238898038469
#
#
# after optimization:
# Timestamp = 55, Vehicle = LR.0
# Estimation: (162.205, 90.9048, 1.06323)
#
# GroundTruth: (161.151, 92, 1.5708)
#
# Difference: (-1.0545686059375043, 1.0952453299719735, -0.507568691107672)
# Timestamp = 55, Vehicle = LR.1
# Estimation: (152.148, 106.344, 1.44038)
#
# GroundTruth: (152.469, 95.2, 1.5708)
#
# Difference: (0.32156620647299405, -11.1439547940751, -0.130420889285035)
# Timestamp = 55, Vehicle = RL.0
# Estimation: (34.9377, 99.2041, -1.39714)
#
# GroundTruth: (39.773, 108, -1.5708)
#
# Difference: (4.835378024255554, 8.795923502470359, 0.1736515516599537)
#
#
# end time 55
#
# time: 56
# current time: 56.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:171.64650741040506, y:92.0, angle:1.5707963267948966
# LR.1: x:159.6206735848016, y:95.2, angle:1.5707963267948966
# RL.0: x:31.304809000838375, y:108.0, angle:4.71238898038469
#
#
# after optimization:
# Timestamp = 56, Vehicle = LR.0
# Estimation: (173.081, 84.1288, 1.59456)
#
# GroundTruth: (171.647, 92, 1.5708)
#
# Difference: (-1.4349906441294138, 7.871242015554401, 0.02376282319139615)
# Timestamp = 56, Vehicle = LR.1
# Estimation: (159.959, 97.4593, 2.02292)
#
# GroundTruth: (159.621, 95.2, 1.5708)
#
# Difference: (-0.33795923693622854, -2.259348327103311, 0.45212385960583135)
# Timestamp = 56, Vehicle = RL.0
# Estimation: (25.6991, 111.84, -1.71926)
#
# GroundTruth: (31.3048, 108, -1.5708)
#
# Difference: (5.605679767339623, -3.840362432288245, -0.14846248410526702)
#
#
# end time 56
#
# time: 57
# current time: 57.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:181.51895978730823, y:92.0, angle:1.5707963267948966
# LR.1: x:167.32536973280764, y:95.2, angle:1.5707963267948966
# RL.0: x:22.232803358164205, y:108.0, angle:4.71238898038469
#
#
# after optimization:
# Timestamp = 57, Vehicle = LR.0
# Estimation: (187.662, 91.5112, 1.90101)
#
# GroundTruth: (181.519, 92, 1.5708)
#
# Difference: (-6.143073777056486, 0.488783224695041, 0.33021393151416356)
# Timestamp = 57, Vehicle = LR.1
# Estimation: (165.318, 93.7895, 1.47365)
#
# GroundTruth: (167.325, 95.2, 1.5708)
#
# Difference: (2.0077178234101325, 1.410457794119182, -0.09715088232458859)
# Timestamp = 57, Vehicle = RL.0
# Estimation: (15.8693, 103.601, -2.30283)
#
# GroundTruth: (22.2328, 108, -1.5708)
#
# Difference: (6.363456094106098, 4.399108836227512, -0.7320381920242307)
#
#
# end time 57
#
# time: 58
# current time: 58.0
# current vehicle list: ('LR.0', 'LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.0: x:191.7795750550564, y:92.0, angle:1.5707963267948966
# LR.1: x:175.2671806787188, y:95.2, angle:1.5707963267948966
# RL.0: x:13.540274289786169, y:108.0, angle:4.71238898038469
#
#
# after optimization:
# Timestamp = 58, Vehicle = LR.0
# Estimation: (186.803, 87.8495, 1.79211)
#
# GroundTruth: (191.78, 92, 1.5708)
#
# Difference: (4.976907409395437, 4.150511647686031, 0.22131197091452778)
# Timestamp = 58, Vehicle = LR.1
# Estimation: (185.498, 89.4178, 1.51299)
#
# GroundTruth: (175.267, 95.2, 1.5708)
#
# Difference: (-10.230333502436224, 5.782220366971359, -0.05780951688692606)
# Timestamp = 58, Vehicle = RL.0
# Estimation: (9.59396, 114.629, -1.56034)
#
# GroundTruth: (13.5403, 108, -1.5708)
#
# Difference: (3.946316112420499, -6.629421843253837, 0.010460518156548528)
#
#
# end time 58
#
# time: 59
# current time: 59.0
# current vehicle list: ('LR.1', 'RL.0')
# departed vehicle list: ()
# arrived vehicle list: ('LR.0',)
# LR.1: x:182.79525001505937, y:95.2, angle:1.5707963267948966
# RL.0: x:5.173695975399625, y:108.0, angle:4.71238898038469
#
#
# after optimization:
# Timestamp = 59, Vehicle = LR.1
# Estimation: (184.323, 99.4458, 1.45631)
#
# GroundTruth: (182.795, 95.2, 1.5708)
#
# Difference: (-1.5273281256587836, -4.245752829183999, -0.11448318416169158)
# Timestamp = 59, Vehicle = RL.0
# Estimation: (5.56766, 113.596, -1.15895)
#
# GroundTruth: (5.1737, 108, -1.5708)
#
# Difference: (-0.39396635678198777, -5.595614119525024, 0.41185118522695463)
#
#
# end time 59
#
# time: 60
# current time: 60.0
# current vehicle list: ('LR.1',)
# departed vehicle list: ()
# arrived vehicle list: ('RL.0',)
# LR.1: x:190.74460783594444, y:95.2, angle:1.5707963267948966
#
#
# after optimization:
# Timestamp = 60, Vehicle = LR.1
# Estimation: (187.599, 98.4067, 1.69728)
#
# GroundTruth: (190.745, 95.2, 1.5708)
#
# Difference: (3.1456060106339976, -3.2066801106113445, 0.12648002772775624)
#
#
# end time 60
#
# time: 61
# current time: 61.0
# current vehicle list: ('LR.1',)
# departed vehicle list: ()
# arrived vehicle list: ()
# LR.1: x:198.29013951302736, y:95.2, angle:1.5707963267948966
#
#
# after optimization:
# Timestamp = 61, Vehicle = LR.1
# Estimation: (198.203, 90.714, 1.93564)
#
# GroundTruth: (198.29, 95.2, 1.5708)
#
# Difference: (0.08679516212220051, 4.485973487663173, 0.36484334964604004)
#
#
# end time 61
#
# time: 62
# time: 63

# %%
df
# Out:
#      timestamp vehicle  groundtruth_x  groundtruth_y  groundtruth_theta  \
# 0            3    DU.0      92.000000     194.900000           3.141593
# 1            4    DU.0      92.000000     192.756856           3.141593
# 2            5    DU.0      92.000000     189.206510           3.141593
# 3            6    DU.0      92.000000     184.120272           3.141593
# 4            6    DU.1      92.000000     194.900000           3.141593
# ..         ...     ...            ...            ...                ...
# 366         58    RL.0      13.540274     108.000000          -1.570796
# 367         59    LR.1     182.795250      95.200000           1.570796
# 368         59    RL.0       5.173696     108.000000          -1.570796
# 369         60    LR.1     190.744608      95.200000           1.570796
# 370         61    LR.1     198.290140      95.200000           1.570796
#
#      estimation_x  estimation_y  estimation_theta  difference_x  difference_y  \
# 0       83.878273    197.958782          2.957226      8.121727     -3.058782
# 1       97.145926    188.792724          2.336936     -5.145926      3.964132
# 2       93.185475    182.147225          2.450031     -1.185475      7.059285
# 3       97.322752    185.061569          2.826837     -5.322752     -0.941297
# 4       86.276381    190.392046         -2.966189      5.723619      4.507954
# ..            ...           ...               ...           ...           ...
# 366      9.593958    114.629422         -1.560336      3.946316     -6.629422
# 367    184.322578     99.445753          1.456313     -1.527328     -4.245753
# 368      5.567662    113.595614         -1.158945     -0.393966     -5.595614
# 369    187.599002     98.406680          1.697276      3.145606     -3.206680
# 370    198.203344     90.714027          1.935640      0.086795      4.485973
#
#      difference_theta
# 0           -0.184367
# 1           -0.804657
# 2           -0.691562
# 3           -0.314755
# 4            0.175404
# ..                ...
# 366          0.010461
# 367         -0.114483
# 368          0.411851
# 369          0.126480
# 370          0.364843
#
# [371 rows x 11 columns]

# %%
error_x = np.sqrt(np.mean(df["difference_x"]**2))
error_y = np.sqrt(np.mean(df["difference_y"]**2))
error_theta = np.sqrt(np.mean(df["difference_theta"]**2))
print(error_x, error_y, error_theta / np.pi * 180)
# Out:
# 5.04925180847583 4.915707834334122 20.243081059392686
